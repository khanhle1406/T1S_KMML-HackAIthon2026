# %%
# !pip install -q -U transformers && pip install -q accelerate sentencepiece torchvision pillow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 96.9 MB/s eta 0:00:00:00:01:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 93.9 MB/s eta 0:00:00:00:01:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.

# %%
from huggingface_hub import login, whoami

login()
print(whoami())
# Out:
# {'type': 'user', 'id': '69876798b92dcf60f8975a59', 'name': 'BaeBaeBoo1010', 'fullname': 'Khánh Lê', 'email': 'khanhle14062006@gmail.com', 'emailVerified': True, 'canPay': False, 'billingMode': 'prepaid', 'periodEnd': 1782864000, 'isPro': False, 'avatarUrl': '/avatars/44e75d6df94b8c89c22e5274755a2c03.svg', 'orgs': [], 'auth': {'type': 'access_token', 'accessToken': {'displayName': 'test-qwen', 'role': 'read', 'createdAt': '2026-06-15T04:08:40.420Z'}}}

# %%
import json

path = "/kaggle/input/datasets/khanhle1406/public-test-1780368312-json/public-test_1780368312.json"

with open(path, "r", encoding="utf-8") as f:
    data = json.load(f)

print("Số câu hỏi:", len(data))
# Out:
# Số câu hỏi: 463

# %% [markdown]
# # Load Model

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
os.environ["TOKENIZERS_PARALLELISM"] = "false"
import json
import re
import torch
import gc
from concurrent.futures import ThreadPoolExecutor
from transformers import AutoProcessor, AutoModelForImageTextToText, LogitsProcessor, LogitsProcessorList

# =====================================================
# 1. BỘ KHÓA TOKEN (OPTIMIZED)
# =====================================================
class ChoiceLogitsProcessor(LogitsProcessor):
    def __init__(self, tokenizer, choices="ABCDEFGHIJKLMNOPQRSTUVWXYZ"):
        self.allowed_token_ids = set()
        vocab = tokenizer.get_vocab()
        for token_str, token_id in vocab.items():
            clean_token = token_str.replace(' ', '').replace('Ġ', '').replace('\n', '').replace('<0x0A>', '').strip()
            if len(clean_token) == 1 and clean_token.upper() in choices:
                self.allowed_token_ids.add(token_id)
        
        for char in choices:
            for prefix in ["", " ", "\n"]:
                for c in [char, char.lower()]:
                    tids = tokenizer.encode(prefix + c, add_special_tokens=False)
                    if tids:
                        self.allowed_token_ids.add(tids[-1])
                        
        self.allowed_token_ids = list(self.allowed_token_ids)
        self.mask = None
        
    def __call__(self, input_ids, scores):
        # Optimizing mask creation: avoid allocating new memory and running multiplication on every step
        if self.mask is None or self.mask.device != scores.device:
            self.mask = torch.full((scores.size(-1),), float('-inf'), device=scores.device)
            self.mask[self.allowed_token_ids] = 0.0
        return scores + self.mask

# =====================================================
# 2. DỌN DẸP VRAM & KHỞI TẠO MODEL (OPTIMIZED)
# =====================================================
# Giải phóng bộ nhớ của các lần chạy trước để tránh lỗi CUDA Out of Memory (OOM) trong Jupyter
for var_name in ['models', 'model', 'processors', 'processor', 'inputs', 'outputs', 'outputs_step1', 'inputs_step2', 'outputs_step2']:
    if var_name in globals():
        print(f"Xóa biến hệ thống cũ: {var_name}")
        del globals()[var_name]

gc.collect()
torch.cuda.empty_cache()

MODEL_NAME = "Qwen/Qwen3.5-4B"

num_gpus = torch.cuda.device_count()
devices = [f"cuda:{i}" for i in range(num_gpus)] if num_gpus > 0 else ["cpu"]
models = []
processors = []

print(f"Phát hiện {len(devices)} thiết bị. Đang tải model và processor...")
for device in devices:
    # Tải processor riêng biệt cho mỗi GPU để tránh tranh chấp bộ nhớ (lỗi Rust "Already borrowed" của Fast Tokenizer)
    proc = AutoProcessor.from_pretrained(MODEL_NAME, trust_remote_code=True)
    proc.tokenizer.padding_side = "left"
    if proc.tokenizer.pad_token is None:
        proc.tokenizer.pad_token = proc.tokenizer.eos_token
    processors.append(proc)

    # Load model trên từng GPU độc lập
    model = AutoModelForImageTextToText.from_pretrained(
        MODEL_NAME,
        trust_remote_code=True,
        dtype=torch.float16,
        device_map={"": device},
        low_cpu_mem_usage=True,
        attn_implementation="sdpa"
    )
    model.eval()
    models.append(model)
print("✅ Tải model và processor hoàn tất!")

# =====================================================
# Out:
# Phát hiện 2 thiết bị. Đang tải model và processor...
# preprocessor_config.json:   0%|          | 0.00/390 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/12.8M [00:00<?, ?B/s]
# video_preprocessor_config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# Loading weights:   0%|          | 0/723 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/723 [00:00<?, ?it/s]
# ✅ Tải model và processor hoàn tất!

# %% [markdown]
# # Load questions and answers

# %%
# 3. LOAD DATA & PHÂN LOẠI
# =====================================================
GROUND_TRUTH = {
    "test_0001": "A", "test_0002": "B", "test_0003": "B",
    "test_0004": "C", "test_0005": "C", "test_0006": "A",
    "test_0007": "B", "test_0008": "B", "test_0009": "C",
    "test_0010": "D", "test_0011": "C", "test_0012": "A",
    "test_0013": "A", "test_0014": "B", "test_0015": "C",
    "test_0016": "A", "test_0017": "B", "test_0018": "B",
    "test_0019": "D", "test_0020": "A", "test_0021": "E",
    "test_0022": "D", "test_0023": "C", "test_0024": "C",
    "test_0025": "B", "test_0026": "B", "test_0027": "A",
    "test_0028": "A", "test_0029": "D", "test_0030": "B",
    "test_0031": "A", "test_0032": "A", "test_0033": "C",
    "test_0034": "A", "test_0035": "D", "test_0036": "A",
    "test_0037": "F", "test_0038": "B", "test_0039": "A",
    "test_0040": "A", "test_0041": "A", "test_0042": "A",
    "test_0043": "E", "test_0044": "A", "test_0045": "B",
    "test_0046": "B", "test_0047": "A", "test_0048": "A",
    "test_0049": "B", "test_0050": "A", "test_0051": "B",
    "test_0052": "A", "test_0053": "B", "test_0054": "D",
    "test_0055": "B", "test_0056": "A", "test_0057": "C",
    "test_0058": "B", "test_0059": "B", "test_0060": "B",
    "test_0061": "B", "test_0062": "D", "test_0063": "B",
    "test_0064": "B", "test_0065": "D", "test_0066": "B",
    "test_0067": "A", "test_0068": "B", "test_0069": "A",
    "test_0070": "C", "test_0071": "C", "test_0072": "C",
    "test_0073": "C", "test_0074": "B", "test_0075": "C",
    "test_0076": "D", "test_0077": "A", "test_0078": "A",
    "test_0079": "B", "test_0080": "B", "test_0081": "C",
    "test_0082": "D", "test_0083": "B", "test_0084": "A",
    "test_0085": "C", "test_0086": "C", "test_0087": "B",
    "test_0088": "B", "test_0089": "B", "test_0090": "A",
    "test_0091": "B", "test_0092": "A", "test_0093": "A",
    "test_0094": "C", "test_0095": "A", "test_0096": "A",
    "test_0097": "A", "test_0098": "A", "test_0099": "B",
    "test_0100": "D", "test_0101": "C", "test_0102": "C",
    "test_0103": "B", "test_0104": "B", "test_0105": "C",
    "test_0106": "C", "test_0107": "B", "test_0108": "C",
    "test_0109": "A", "test_0110": "A", "test_0111": "B",
    "test_0112": "G", "test_0113": "C", "test_0114": "A",
    "test_0115": "D", "test_0116": "A", "test_0117": "A",
    "test_0118": "E", "test_0119": "A", "test_0120": "C",
    "test_0121": "C", "test_0122": "A", "test_0123": "B",
    "test_0124": "B", "test_0125": "D", "test_0126": "B",
    "test_0127": "A", "test_0128": "A", "test_0129": "A",
    "test_0130": "A", "test_0131": "C", "test_0132": "B",
    "test_0133": "A", "test_0134": "B", "test_0135": "B",
    "test_0136": "B", "test_0137": "C", "test_0138": "A",
    "test_0139": "D", "test_0140": "C", "test_0141": "A",
    "test_0142": "C", "test_0143": "B", "test_0144": "A",
    "test_0145": "A", "test_0146": "C", "test_0147": "E",
    "test_0148": "B", "test_0149": "C", "test_0150": "C",
    "test_0151": "F", "test_0152": "A", "test_0153": "D",
    "test_0154": "C", "test_0155": "A", "test_0156": "B",
    "test_0157": "B", "test_0158": "A", "test_0159": "D",
    "test_0160": "D", "test_0161": "A", "test_0162": "C",
    "test_0163": "D", "test_0164": "A", "test_0165": "B",
    "test_0166": "B", "test_0167": "C", "test_0168": "D",
    "test_0169": "B", "test_0170": "A", "test_0171": "B",
    "test_0172": "B", "test_0173": "D", "test_0174": "B",
    "test_0175": "B", "test_0176": "A", "test_0177": "A",
    "test_0178": "A", "test_0179": "B", "test_0180": "A",
    "test_0181": "A", "test_0182": "C", "test_0183": "B",
    "test_0184": "D", "test_0185": "C", "test_0186": "C",
    "test_0187": "D", "test_0188": "B", "test_0189": "B",
    "test_0190": "D", "test_0191": "B", "test_0192": "B",
    "test_0193": "B", "test_0194": "C", "test_0195": "B",
    "test_0196": "A", "test_0197": "B", "test_0198": "A",
    "test_0199": "B", "test_0200": "D", "test_0201": "A",
    "test_0202": "D", "test_0203": "B", "test_0204": "A",
    "test_0205": "B", "test_0206": "D", "test_0207": "B",
    "test_0208": "B", "test_0209": "D", "test_0210": "B",
    "test_0211": "A", "test_0212": "A", "test_0213": "D",
    "test_0214": "B", "test_0215": "A", "test_0216": "B",
    "test_0217": "B", "test_0218": "A", "test_0219": "B",
    "test_0220": "J", "test_0221": "A", "test_0222": "C",
    "test_0223": "C", "test_0224": "B", "test_0225": "C",
    "test_0226": "A", "test_0227": "A", "test_0228": "J",
    "test_0229": "D", "test_0230": "B", "test_0231": "B",
    "test_0232": "A", "test_0233": "A", "test_0234": "A",
    "test_0235": "B", "test_0236": "A", "test_0237": "A",
    "test_0238": "B", "test_0239": "B", "test_0240": "B",
    "test_0241": "D", "test_0242": "D", "test_0243": "B",
    "test_0244": "A", "test_0245": "E", "test_0246": "E",
    "test_0247": "D", "test_0248": "B", "test_0249": "B",
    "test_0250": "D", "test_0251": "H", "test_0252": "C",
    "test_0253": "D", "test_0254": "B", "test_0255": "C",
    "test_0256": "C", "test_0257": "C", "test_0258": "B",
    "test_0259": "A", "test_0260": "B", "test_0261": "B",
    "test_0262": "B", "test_0263": "C", "test_0264": "C",
    "test_0265": "A", "test_0266": "A", "test_0267": "B",
    "test_0268": "B", "test_0269": "I", "test_0270": "D",
    "test_0271": "D", "test_0272": "A", "test_0273": "D",
    "test_0274": "A", "test_0275": "A", "test_0276": "B",
    "test_0277": "A", "test_0278": "E", "test_0279": "B",
    "test_0280": "B", "test_0281": "A", "test_0282": "A",
    "test_0283": "A", "test_0284": "C", "test_0285": "B",
    "test_0286": "C", "test_0287": "D", "test_0288": "B",
    "test_0289": "C", "test_0290": "A", "test_0291": "B",
    "test_0292": "B", "test_0293": "D", "test_0294": "C",
    "test_0295": "A", "test_0296": "B", "test_0297": "D",
    "test_0298": "B", "test_0299": "B", "test_0300": "A",
    "test_0301": "A", "test_0302": "A", "test_0303": "A",
    "test_0304": "B", "test_0305": "C", "test_0306": "A",
    "test_0307": "H", "test_0308": "B", "test_0309": "B",
    "test_0310": "E", "test_0311": "A", "test_0312": "A",
    "test_0313": "A", "test_0314": "A", "test_0315": "A",
    "test_0316": "D", "test_0317": "C", "test_0318": "C",
    "test_0319": "A", "test_0320": "D", "test_0321": "C",
    "test_0322": "B", "test_0323": "A", "test_0324": "C",
    "test_0325": "A", "test_0326": "E", "test_0327": "B",
    "test_0328": "D", "test_0329": "A", "test_0330": "D",
    "test_0331": "C", "test_0332": "A", "test_0333": "B",
    "test_0334": "A", "test_0335": "A", "test_0336": "B",
    "test_0337": "B", "test_0338": "C", "test_0339": "A",
    "test_0340": "C", "test_0341": "D", "test_0342": "B",
    "test_0343": "B", "test_0344": "C", "test_0345": "A",
    "test_0346": "B", "test_0347": "B", "test_0348": "H",
    "test_0349": "C", "test_0350": "C", "test_0351": "G",
    "test_0352": "B", "test_0353": "B", "test_0354": "B",
    "test_0355": "A", "test_0356": "C", "test_0357": "C",
    "test_0358": "A", "test_0359": "B", "test_0360": "D",
    "test_0361": "A", "test_0362": "A", "test_0363": "B",
    "test_0364": "B", "test_0365": "C", "test_0366": "C",
    "test_0367": "C", "test_0368": "B", "test_0369": "A",
    "test_0370": "C", "test_0371": "B", "test_0372": "A",
    "test_0373": "B", "test_0374": "A", "test_0375": "C",
    "test_0376": "C", "test_0377": "D", "test_0378": "D",
    "test_0379": "B", "test_0380": "B", "test_0381": "E",
    "test_0382": "B", "test_0383": "B", "test_0384": "A",
    "test_0385": "B", "test_0386": "A", "test_0387": "C",
    "test_0388": "C", "test_0389": "A", "test_0390": "A",
    "test_0391": "A", "test_0392": "B", "test_0393": "B",
    "test_0394": "A", "test_0395": "A", "test_0396": "D",
    "test_0397": "E", "test_0398": "D", "test_0399": "D",
    "test_0400": "A", "test_0401": "A", "test_0402": "E",
    "test_0403": "A", "test_0404": "C", "test_0405": "C",
    "test_0406": "B", "test_0407": "B", "test_0408": "A",
    "test_0409": "B", "test_0410": "B", "test_0411": "C",
    "test_0412": "A", "test_0413": "A", "test_0414": "D",
    "test_0415": "D", "test_0416": "B", "test_0417": "D",
    "test_0418": "D", "test_0419": "A", "test_0420": "A",
    "test_0421": "A", "test_0422": "A", "test_0423": "D",
    "test_0424": "B", "test_0425": "D", "test_0426": "B",
    "test_0427": "B", "test_0428": "C", "test_0429": "B",
    "test_0430": "A", "test_0431": "C", "test_0432": "C",
    "test_0433": "B", "test_0434": "B", "test_0435": "A",
    "test_0436": "C", "test_0437": "B", "test_0438": "C",
    "test_0439": "A", "test_0440": "A", "test_0441": "B",
    "test_0442": "A", "test_0443": "C", "test_0444": "A",
    "test_0445": "B", "test_0446": "A", "test_0447": "B",
    "test_0448": "A", "test_0449": "D", "test_0450": "A",
    "test_0451": "B", "test_0452": "B", "test_0453": "A",
    "test_0454": "B", "test_0455": "B", "test_0456": "C",
    "test_0457": "D", "test_0458": "D", "test_0459": "C",
    "test_0460": "A", "test_0461": "B", "test_0462": "C",
    "test_0463": "D"
}
JSON_PATH = "/kaggle/input/datasets/khanhle1406/public-test-1780368312-json/public-test_1780368312.json"

with open(JSON_PATH, "r", encoding="utf-8") as f:
    questions = json.load(f)[:200]

# %% [markdown]
# # Run Model

# %% [markdown]
# * Method 1

# %%
def normalize_prediction(pred_letter, item):
    if not pred_letter or pred_letter not in LETTERS:
        return "A"
    try:
        idx = LETTERS.index(pred_letter)
        if idx >= len(item["choices"]):
            return "A"
        choice_text = str(item["choices"][idx]).strip().lower()
        for i, choice in enumerate(item["choices"]):
            if str(choice).strip().lower() == choice_text:
                return LETTERS[i]
    except Exception:
        pass
    return pred_letter

LETTERS = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

def is_reasoning_question(question):
    return "là bao nhiêu" in question.lower()

reasoning_questions = [q for q in questions if is_reasoning_question(q["question"])]
knowledge_questions = [q for q in questions if not is_reasoning_question(q["question"])]

SYSTEM_KNOWLEDGE = "Chỉ trả về 1 chữ cái duy nhất (A, B, C, D, E, F, G, H, I, J)."
SYSTEM_REASONING = """Bạn là chuyên gia. Hãy suy luận giải quyết bài toán thật chi tiết. 
LƯU Ý QUAN TRỌNG: 
1. Bạn có rất nhiều khoảng trống để tính toán, KHÔNG ĐƯỢC DỪNG LẠI GIỮA CHỪNG. 
2. Nếu kết quả là phân số, biểu thức hoặc có chứa số Pi (π), BẮT BUỘC quy đổi ra số thập phân xấp xỉ để tìm đáp án gần nhất.
3. Chốt lại kết quả rõ ràng ở cuối."""

def build_messages(question_items, system_prompt):
    messages = []
    for item in question_items:
        choices_text = "\n".join(f"{LETTERS[i]}. {choice}" for i, choice in enumerate(item["choices"]))
        user_prompt = f"Câu hỏi:\n{item['question']}\n\nLựa chọn:\n{choices_text}\n\nNhiệm vụ: Chọn đúng 1 đáp án."
        messages.append([
            {"role": "system", "content": [{"type": "text", "text": system_prompt}]},
            {"role": "user", "content": [{"type": "text", "text": user_prompt}]}
        ])
    return messages

# =====================================================
# 4. HÀM CHẠY KNOWLEDGE (TỐI ƯU HÓA)
# =====================================================
def run_knowledge_gpu(question_items, max_new_tokens, model, device, processor):
    if not question_items: return {}
    preds = {}
    BATCH_SIZE = 8  # Xử lý song song batch lớn trên GPU T4
    
    # Khởi tạo ChoiceLogitsProcessor một lần duy nhất cho mỗi luồng worker
    logits_processor = LogitsProcessorList([ChoiceLogitsProcessor(processor.tokenizer)])
    
    for i in range(0, len(question_items), BATCH_SIZE):
        mini_batch = question_items[i:i + BATCH_SIZE]
        batch_messages = build_messages(mini_batch, SYSTEM_KNOWLEDGE)
        texts = [processor.apply_chat_template(msg, tokenize=False, add_generation_prompt=True) + "Đáp án:" for msg in batch_messages]
        
        inputs = processor(text=texts, padding=True, truncation=True, return_tensors="pt").to(device)
        
        with torch.inference_mode():
            outputs = model.generate(
                **inputs, max_new_tokens=1, do_sample=False, pad_token_id=processor.tokenizer.eos_token_id, logits_processor=logits_processor
            )

        answers = processor.batch_decode(outputs[:, inputs.input_ids.shape[1]:], skip_special_tokens=True)
        
        for item, ans in zip(mini_batch, answers):
            raw = ans.strip()
            active_letters = LETTERS[:len(item["choices"])]
            m = re.search(rf"\b([{active_letters}])\b", raw.upper())
            if not m:
                m = re.search(rf"([{active_letters}])", raw.upper())
            pred_letter = m.group(1) if m else "A"
            pred_letter = normalize_prediction(pred_letter, item)
            preds[item["qid"]] = {"pred": pred_letter, "raw": raw}
            
        del inputs, outputs
        
    return preds

# =====================================================
# 5. HÀM CHẠY REASONING (TỐI ƯU HÓA)
# =====================================================
def run_reasoning_gpu(question_items, max_new_tokens, model, device, processor):
    if not question_items: return {}
    preds = {}
    BATCH_SIZE = 2  # Batch_size = 2 để cân đối VRAM của GPU T4 khi sinh chuỗi dài
    
    logits_processor = LogitsProcessorList([ChoiceLogitsProcessor(processor.tokenizer)])
    
    for i in range(0, len(question_items), BATCH_SIZE):
        mini_batch = question_items[i:i + BATCH_SIZE]
        batch_messages = build_messages(mini_batch, SYSTEM_REASONING)
        texts = [processor.apply_chat_template(msg, tokenize=False, add_generation_prompt=True) + "Suy luận:\n" for msg in batch_messages]
        
        # --- BƯỚC 1: SUY LUẬN ---
        inputs = processor(text=texts, padding=True, truncation=True, return_tensors="pt").to(device)
        with torch.inference_mode():
            outputs_step1 = model.generate(
                **inputs, max_new_tokens=max_new_tokens, do_sample=False, pad_token_id=processor.tokenizer.eos_token_id
            )
        
        reasoning_texts = processor.batch_decode(outputs_step1[:, inputs.input_ids.shape[1]:], skip_special_tokens=True)
        
        # --- BƯỚC 2: ÉP CHỐT ---
        forced_texts = [text + "\n\nVậy đáp án đúng là:" for text in processor.batch_decode(outputs_step1, skip_special_tokens=True)]
        inputs_step2 = processor(text=forced_texts, padding=True, truncation=True, return_tensors="pt").to(device)
        
        with torch.inference_mode():
            outputs_step2 = model.generate(
                **inputs_step2, max_new_tokens=1, do_sample=False, pad_token_id=processor.tokenizer.eos_token_id, logits_processor=logits_processor
            )
        
        final_letters = processor.batch_decode(outputs_step2[:, inputs_step2.input_ids.shape[1]:], skip_special_tokens=True)
        
        for item, reasoning_part, final_letter in zip(mini_batch, reasoning_texts, final_letters):
            raw_combined = reasoning_part.strip() + "\n\n[ÉP CHỐT]: " + final_letter.strip()
            active_letters = LETTERS[:len(item["choices"])]
            m = re.search(rf"\b([{active_letters}])\b", final_letter.upper())
            if not m:
                m = re.search(rf"([{active_letters}])", final_letter.upper())
            pred_letter = m.group(1) if m else "A"
            pred_letter = normalize_prediction(pred_letter, item)
            preds[item["qid"]] = {"pred": pred_letter, "raw": raw_combined}
            
        del inputs, outputs_step1, inputs_step2, outputs_step2
        
    return preds

# =====================================================
# 6. TRÌNH QUẢN LÝ ĐA LUỒNG (OPTIMIZED)
# =====================================================
def run_batch(question_items, mode, max_new_tokens):
    if not question_items: return {}

    num_workers = len(models)
    # Chia danh sách lớn thành các Khối (Chunks) giao cho từng GPU
    chunk_size = (len(question_items) + num_workers - 1) // num_workers
    chunks = [question_items[i:i + chunk_size] for i in range(0, len(question_items), chunk_size)]
    
    results = {}
    
    with ThreadPoolExecutor(max_workers=num_workers) as executor:
        futures = []
        for i, chunk in enumerate(chunks):
            if chunk:
                target_model = models[i % num_workers]
                target_device = devices[i % num_workers] # Dùng chuỗi thiết bị (cuda:x)
                target_processor = processors[i % num_workers] # Dùng processor độc lập để tránh tranh chấp luồng
                func = run_knowledge_gpu if mode == "KNOWLEDGE" else run_reasoning_gpu
                futures.append(executor.submit(func, chunk, max_new_tokens, target_model, target_device, target_processor))
                
        for future in futures:
            results.update(future.result())
            
    return results

# =====================================================
# 7. THỰC THI & HIỂN THỊ
# =====================================================
results = {}

print(f"\n[1/2] Đang xử lý {len(knowledge_questions)} câu hỏi thường (Output 1 ký tự)...")
if knowledge_questions:
    results.update(run_batch(knowledge_questions, mode="KNOWLEDGE", max_new_tokens=1))

print(f"\n[2/2] Đang xử lý {len(reasoning_questions)} câu hỏi 'là bao nhiêu' (Cơ chế 2 bước, Suy luận max 1000 tokens)...")
if reasoning_questions:
    results.update(run_batch(reasoning_questions, mode="REASONING", max_new_tokens=1000))

# =====================================================
# 8. SHOW OUTPUT & EVALUATION (OPTIMIZED FOR BATCH)
# =====================================================
print("\n" + "=" * 100)
print("MODEL OUTPUT")
print("=" * 100)

for item in questions:
    qid = item["qid"]
    mode = "REASONING" if is_reasoning_question(item["question"]) else "KNOWLEDGE"
    res = results.get(qid, {"pred": "?", "raw": "NO OUTPUT"})
    
    print(f"QID   : {qid}")
    print(f"MODE  : {mode}")
    print(f"RAW   :\n{res['raw']}")
    print(f"PRED  : {res['pred']}")
    print("-" * 100)

correct = 0
total_evaluated = 0
print("\n" + "=" * 100 + "\nEVALUATION\n" + "=" * 100)
for item in questions:
    qid = item["qid"]
    if qid in GROUND_TRUTH:
        gt = GROUND_TRUTH[qid]
        pred = results.get(qid, {}).get("pred", "?")
        ok = pred == gt
        if ok:
            correct += 1
        total_evaluated += 1
        print(f"{qid:12s} | Pred={pred:2s} | GT={gt:2s} | {'✓' if ok else '✗'}")

print("=" * 100)
if total_evaluated > 0:
    print(f"Correct : {correct}/{total_evaluated}\nAccuracy: {correct / total_evaluated:.2%}")
else:
    print("No questions with ground truth were evaluated.")
print("=" * 100)
# Out:
# [1/2] Đang xử lý 8 câu hỏi thường (Output 1 ký tự)...
#
# [2/2] Đang xử lý 2 câu hỏi 'là bao nhiêu' (Cơ chế 2 bước, Suy luận max 1000 tokens)...
#
# ====================================================================================================
# MODEL OUTPUT
# ====================================================================================================
# QID   : test_0031
# MODE  : KNOWLEDGE
# RAW   :
# A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0032
# MODE  : KNOWLEDGE
# RAW   :
# A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0033
# MODE  : KNOWLEDGE
# RAW   :
# C
# PRED  : C
# ----------------------------------------------------------------------------------------------------
# QID   : test_0034
# MODE  : REASONING
# RAW   :
# 1.  **Phân tích đề bài:**
#     *   Hàm tổng chi phí (TC): $TC = 100 + 5Q + 0.5Q^2$.
#     *   Thị trường cạnh tranh (Perfect Competition).
#     *   Yêu cầu: Tìm Chi phí biến đổi trung bình (AVC) tối thiểu tại điểm đóng cửa.
#     *   Lưu ý: "Tại điểm đóng cửa" thường liên quan đến điều kiện $P = AVC$ (điểm đóng cửa ngắn hạn). Tuy nhiên, câu hỏi hỏi cụ thể là "AVC tối thiểu". Trong lý thuyết kinh tế vi mô, điểm đóng cửa (shutdown point) xảy ra khi $P = AVC_{min}$. Do đó, việc tìm $AVC_{min}$ chính là tìm giá trị của $AVC$ tại điểm đóng cửa.
#
# 2.  **Xác định hàm Chi phí biến đổi (TVC):**
#     *   $TC = TFC + TVC$.
#     *   Từ $TC = 100 + 5Q + 0.5Q^2$, ta thấy $TFC = 100$ (chi phí cố định).
#     *   $TVC = 5Q + 0.5Q^2$.
#
# 3.  **Xác định hàm Chi phí biến đổi trung bình (AVC):**
#     *   $AVC = \frac{TVC}{Q}$.
#     *   Thay $TVC$ vào: $AVC = \frac{5Q + 0.5Q^2}{Q}$.
#     *   Rút gọn: $AVC = 5 + 0.5Q$.
#
# 4.  **Tìm điểm tối thiểu của AVC:**
#     *   Hàm $AVC = 5 + 0.5Q$ là một hàm số bậc nhất (dạng đường thẳng dốc lên).
#     *   Đạo hàm theo $Q$: $\frac{d(AVC)}{dQ} = 0.5$.
#     *   Đạo hàm này luôn dương ($0.5 > 0$), nghĩa là hàm $AVC$ luôn tăng khi $Q$ tăng.
#     *   Điều này có nghĩa là $AVC$ đạt giá trị nhỏ nhất tại $Q = 0$.
#     *   Tuy nhiên, trong thực tế kinh tế, $Q > 0$.
#     *   Hãy kiểm tra lại hàm TC. Có thể đề bài có lỗi hoặc tôi hiểu sai cấu trúc?
#     *   Thông thường, hàm chi phí bậc 2 như $TC = F + aQ + bQ^2$ (với $b > 0$) sẽ tạo ra $MC$ và $AVC$ là đường cong U hình (có cực tiểu).
#     *   $MC = \frac{dTC}{dQ} = 5 + Q$.
#     *   $AVC = 5 + 0.5Q$.
#     *   Nếu $AVC = 5 + 0.5Q$, thì $AVC$ giảm khi $Q$ nhỏ và tăng khi $Q$ lớn? Không, đạo hàm là $0.5 > 0$, nên nó luôn tăng.
#     *   Tại sao lại có "tối thiểu"?
#     *   Có thể đề bài muốn hỏi "Chi phí biến đổi trung bình (AVC) tối thiểu" dựa trên giả định thông thường về hàm chi phí bậc 2, nhưng ở đây hệ số của $Q$ là dương ($5Q$) và hệ số của $Q^2$ cũng dương ($0.5Q^2$).
#     *   Hãy xem lại công thức AVC: $AVC = \frac{5Q + 0.5Q^2}{Q} = 5 + 0.5Q$.
#     *   Với $Q > 0$, giá trị nhỏ nhất của $5 + 0.5Q$ là khi $Q$ càng nhỏ càng tốt. Giới hạn khi $Q \to 0$, $AVC \to 5$.
#     *   Tuy nhiên, trong các bài toán trắc nghiệm kinh tế vi mô cơ bản, thường gặp trường hợp $TC = F + aQ + bQ^2$ với $b > 0$. Khi đó $MC = a + 2bQ$. $AVC = a + bQ$.
#     *   Nếu $AVC = a + bQ$ với $b > 0$, thì $AVC$ là đường thẳng dốc lên. Điểm tối thiểu nằm tại $Q=0$.
#     *   Nhưng nếu đề bài cho $TC = 100 + 5Q + 0.5Q^2$, thì $AV
#
# [ÉP CHỐT]: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0035
# MODE  : KNOWLEDGE
# RAW   :
# D
# PRED  : D
# ----------------------------------------------------------------------------------------------------
# QID   : test_0036
# MODE  : KNOWLEDGE
# RAW   :
# A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0037
# MODE  : REASONING
# RAW   :
# 1.  **Xác định công thức:** Hệ số giãn nở thời gian (thường ký hiệu là $\gamma$ hoặc Lorentz factor) trong thuyết tương đối hẹp được tính bằng công thức:
#     $$ \gamma = \frac{1}{\sqrt{1 - \frac{v^2}{c^2}}} $$
#     Trong đó:
#     *   $v$ là tốc độ của vật (tàu vũ trụ).
#     *   $c$ là tốc độ ánh sáng.
#
# 2.  **Thay số vào công thức:**
#     *   Theo đề bài, $v = 0.6c$.
#     *   Thay $v$ vào công thức:
#         $$ \gamma = \frac{1}{\sqrt{1 - \frac{(0.6c)^2}{c^2}}} $$
#
# 3.  **Tính toán:**
#     *   Tính bình phương của $v$: $(0.6c)^2 = 0.36c^2$.
#     *   Chia cho $c^2$: $\frac{0.36c^2}{c^2} = 0.36$.
#     *   Tính số trong căn: $1 - 0.36 = 0.64$.
#     *   Tính căn bậc hai: $\sqrt{0.64} = 0.8$.
#     *   Tính nghịch đảo: $\gamma = \frac{1}{0.8}$.
#
# 4.  **Rút gọn kết quả:**
#     *   $\frac{1}{0.8} = \frac{10}{8} = \frac{5}{4} = 1.25$.
#
# 5.  **Kiểm tra lại:**
#     *   $v = 0.6c$ là một trường hợp kinh điển trong vật lý (tam giác Pythagoras 3-4-5).
#     *   $\beta = v/c = 0.6$.
#     *   $\gamma = 1 / \sqrt{1 - 0.6^2} = 1 / \sqrt{1 - 0.36} = 1 / \sqrt{0.64} = 1 / 0.8 = 1.25$.
#     *   Kết quả là 1.25.
#
# 6.  **So sánh với các lựa chọn:**
#     *   A. 0.8
#     *   B. 0.85
#     *   C. 0.9
#     *   D. 0.95
#     *   E. 1.0
#     *   F. 1.25
#     *   G. 1.33
#     *   H. 1.5
#     *   I. 1.75
#     *   J. 2.0
#
#     Kết quả 1.25 khớp với lựa chọn F.
#
# 7.  **Lưu ý về yêu cầu:**
#     *   "BẮT BUỘC quy đổi ra số thập phân xấp xỉ để tìm đáp án gần nhất." -> Kết quả chính xác là 1.25, đây là số thập phân chính xác, không cần xấp xỉ.
#     *   "Chốt lại kết quả rõ ràng ở cuối."
#
# 8.  **Kết luận:** Đáp án là F.
#
# Bây giờ tôi sẽ viết ra quá trình suy luận chi tiết theo yêu cầu.
# </think>
#
# Để giải quyết bài toán này, chúng ta cần áp dụng công thức hệ số giãn nở thời gian (hay còn gọi là hệ số Lorentz) trong thuyết tương đối hẹp của Einstein.
#
# **Bước 1: Xác định công thức tính hệ số giãn nở thời gian $\gamma$**
# Công thức tính hệ số Lorentz là:
# $$ \gamma = \frac{1}{\sqrt{1 - \frac{v^2}{c^2}}} $$
# Trong đó:
# *   $v$ là tốc độ của vật di chuyển (tàu vũ trụ).
# *   $c$ là tốc độ ánh sáng trong chân không.
#
# **Bước 2: Thay số liệu đã cho vào công thức**
# Theo đề bài, tốc độ của tàu vũ trụ là $v = 0.6c$.
# Thay giá trị này vào công thức:
# $$ \gamma = \frac{1}{\sqrt{1 - \frac{(0.6c)^2}{c^2}}} $$
#
# **Bước 3: Thực hiện tính toán**
# 1.  Tính bình phương của $v$:
#     $$ (0.6c)^2 = 0.36c^2 $$
# 2
#
# [ÉP CHỐT]: F
# PRED  : F
# ----------------------------------------------------------------------------------------------------
# QID   : test_0038
# MODE  : KNOWLEDGE
# RAW   :
# B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0039
# MODE  : KNOWLEDGE
# RAW   :
# A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0040
# MODE  : KNOWLEDGE
# RAW   :
# A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# EVALUATION
# ====================================================================================================
# test_0031    | Pred=A  | GT=A  | ✓
# test_0032    | Pred=A  | GT=A  | ✓
# test_0033    | Pred=C  | GT=C  | ✓
# test_0034    | Pred=B  | GT=A  | ✗
# test_0035    | Pred=D  | GT=D  | ✓
# test_0036    | Pred=A  | GT=A  | ✓
# test_0037    | Pred=F  | GT=F  | ✓
# test_0038    | Pred=B  | GT=B  | ✓
# test_0039    | Pred=A  | GT=A  | ✓
# test_0040    | Pred=A  | GT=A  | ✓
# ====================================================================================================
# Correct : 9/10
# Accuracy: 90.00%
# ====================================================================================================

# %% [markdown]
# * Method 2

# %%
def normalize_prediction(pred_letter, item):
    if not pred_letter or pred_letter not in LETTERS:
        return "A"
    try:
        idx = LETTERS.index(pred_letter)
        if idx >= len(item["choices"]):
            return "A"
        choice_text = str(item["choices"][idx]).strip().lower()
        for i, choice in enumerate(item["choices"]):
            if str(choice).strip().lower() == choice_text:
                return LETTERS[i]
    except Exception:
        pass
    return pred_letter

# =====================================================
# PHƯƠNG PHÁP 2: TỐI ƯU HÓA BẰNG LIKELIHOOD & KV CACHE
# =====================================================
import json
import re
import gc
import math
import torch
from concurrent.futures import ThreadPoolExecutor
from transformers.cache_utils import DynamicCache

# CẤU HÌNH PHƯƠNG PHÁP CHẠY LIKELIHOOD:
# True:  Phương pháp Single-Pass cực nhanh, xử lý theo BATCH (Tối ưu nhất cho tốc độ và bộ nhớ)
# False: Phương pháp Multi-Pass KV Cache truyền thống (Tuần tự từng lựa chọn, dùng DynamicCache)
USE_SINGLE_PASS = True

# BẬT/TẮT HIỆU CHUẨN KHÔNG NGỮ CẢNH (CONTENT-FREE CALIBRATION)
# Giúp triệt tiêu thiên kiến chữ cái (letter bias) và chiều dài đáp án
USE_CALIBRATION = True

# Tự động thiết lập hằng số và phân loại câu hỏi (Giúp Cell 7 độc lập với Cell 6)
LETTERS = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
SYSTEM_KNOWLEDGE = "Chỉ trả về 1 chữ cái duy nhất (A, B, C, D, E, F, G, H, I, J)."
SYSTEM_REASONING = r"""Bạn là chuyên gia giải bài tập toán, lý, hóa, kinh tế. Hãy suy luận ngắn gọn, tập trung để tìm đáp án đúng.
Quy tắc:
1. Trình bày suy luận ngắn (dưới 5 dòng), đi thẳng vào công thức, thế số và tính toán trực tiếp.
2. Chốt lại đáp án ở dòng cuối.

Ví dụ 1:
Câu hỏi: Một tụ điện 100 uF được nạp đến 120V. Hằng số thời gian xả qua điện trở 500 ohm là bao nhiêu?
Lựa chọn:
A. 0.05 giây
B. 0.1 giây
C. 0.2 giây
D. 0.5 giây
Nhiệm vụ: Chọn đúng 1 đáp án.
Suy luận:
Hằng số thời gian RC là \tau = R * C = 500 * 100 * 10^-6 = 0.05 giây.
Vậy đáp án đúng là A.

Ví dụ 2:
Câu hỏi: Hàm cầu QD = 200 - 5P, hàm cung QS = -50 + 5P. Giá cân bằng là bao nhiêu?
Lựa chọn:
A. 20
B. 25
C. 30
D. 35
Nhiệm vụ: Chọn đúng 1 đáp án.
Suy luận:
Tại cân bằng: QD = QS <=> 200 - 5P = -50 + 5P <=> 10P = 250 <=> P = 25.
Vậy đáp án đúng là B."""

def is_reasoning_question(item):
    q_text = item["question"]
    choices = item["choices"]
    q_lower = q_text.lower()
    
    # Check for math action words
    has_math_action = False
    if "tính " in q_lower:
        exclude_tinh = [
            "tính chất", "tính mạng", "tính cách", "tính kỷ luật", "tính từ thiện", "tính pháp",
            "tính năng", "tính hướng", "tính đảng", "tính nhân dân", "tính giai cấp", "tính thời sự",
            "tính khoa học", "tính nghệ thuật", "tính chân thực", "tính độc đáo", "tính lịch sử",
            "tính quy luật", "tính khách quan", "tính chủ quan", "tính khả thi", "tính hợp pháp"
        ]
        if not any(e in q_lower for e in exclude_tinh):
            has_math_action = True
    
    # 1. Passage-based questions are always knowledge in this dataset
    passage_prefixes = ["đoạn thông tin:", "đoạn văn:", "title:", "content:", "-- document"]
    if any(q_lower.startswith(p) for p in passage_prefixes):
        return False
        
    # 2. Check for LaTeX math symbols in question
    if "$" in q_text:
        return True

    # 3. Check for numerical/math choices
    def is_numerical_choice(choice):
        text = str(choice).strip()
        if text.startswith("$") and text.endswith("$"):
            return True
        if any(op in text for op in [r"\frac", r"\equiv", r"\pmod", r"\times", r"\sqrt", "^"]):
            return True
        clean = re.sub(r"\s*(g|ml|l|m|cm|kg|usd|đô la|%|cm/s|cm/giây|đơn vị|thaler|đáp án khác|tất cả|cả|đều|giây|ngày|tháng|năm|nguyên tắc|tiến sĩ|lần|độ)\.?$", "", text, flags=re.IGNORECASE)
        clean = clean.replace(",", ".").strip()
        if re.match(r"^[-+]?\d*\.?\d+$", clean):
            return True
        if any(c.isdigit() for c in text):
            if any(op in text for op in ["=", "+", "*", "/", "^"]):
                return True
        return False

    num_choices = [c for c in choices if is_numerical_choice(c)]
    pct_numerical = len(num_choices) / len(choices) if choices else 0
    
    # 4. Calculation/Math keywords
    math_calc_keywords = [
        "tính toán", "tính đạo hàm", "tính tích phân", "tính giới hạn", "tính nguyên hàm",
        "phương trình vi phân", "độ co giãn", "tỷ lệ lạm phát", "gdp danh nghĩa", "gdp thực tế",
        "tốc độ tăng", "tốc độ thay đổi", "điện trở tương đương", "hòa tan", "nồng độ mol",
        "nồng độ phần trăm", "trung hoà dung dịch", "lượng đặt hàng", "giá trị của biểu thức",
        "tổng chi phí", "chi phí biên", "doanh thu biên", "hàm cung", "hàm cầu", "hàm chi phí",
        "hàm sản xuất", "hàm tiêu dùng", "đường đẳng lượng", "số nhân tiền", "eoq", "định luật",
        "biến ngẫu nhiên", "xác suất", "đạo hàm bậc", "tính giá trị", "nghiệm của phương trình",
        "phương trình hoành độ", "tính số", "tốc độ đồng hồ", "lãi kép", "chi phí", "doanh thu",
        "lợi nhuận", "sản lượng", "tốc độ", "gia tốc", "chu kỳ", "tần số", "bán kính", "chiều cao",
        "thể tích", "diện tích", "số dư tài khoản", "khối lượng", "nồng độ", "điện trở", "công suất"
    ]
    has_math_keyword = any(w in q_lower for w in math_calc_keywords)
    
    # Check if the question asks for a calculation value ("bao nhiêu")
    asks_how_much = "bao nhiêu" in q_lower or "thay đổi như thế nào" in q_lower

    # Exclude keywords that indicate lookup of fact, law, history, names, administrative/legal procedures
    legal_history_keywords = [
        "luật", "quy định", "thủ tục", "thời hạn", "chính sách", "nghị định", "thông tư", "điều bộ luật",
        "cấp phép", "chứng nhận", "bảo hiểm", "năm nào", "sinh năm", "mất năm", "ai là", "quốc gia nào",
        "tác giả", "tác phẩm", "nhân vật", "ngày nào", "sự kiện", "lịch sử", "khái niệm", "định nghĩa",
        "thế kỷ", "triều đại", "ngôi chùa", "khai dựng", "biểu hiện của biến đổi khí hậu"
    ]
    has_exclude_keyword = any(w in q_lower for w in legal_history_keywords)

    # 5. Let's decide
    if has_math_action or any(w in q_lower for w in ["chỉ số hhi", "herfindahl-hirschman", "vốn lưu động"]):
        if not has_exclude_keyword:
            return True
            
    if pct_numerical >= 0.5:
        is_all_years = all(re.match(r"^(năm\s+)?\d{4}$", str(c).strip().lower()) for c in choices)
        if is_all_years:
            return False
        if has_exclude_keyword and not has_math_keyword and not asks_how_much:
            return False
        return True

    any_digits_in_choices = any(any(c.isdigit() for c in str(ch)) for ch in choices)
    
    if has_math_keyword and any_digits_in_choices:
        if has_exclude_keyword:
            if any(w in q_lower for w in ["tính", "tính toán", "phương trình", "hàm số", "độ co giãn", "tỷ lệ"]):
                return True
            return False
        return True

    if asks_how_much and any_digits_in_choices:
        if has_exclude_keyword:
            return False
        return True

    return False


reasoning_questions = [q for q in questions if is_reasoning_question(q)]
knowledge_questions = [q for q in questions if not is_reasoning_question(q)]

# Map chữ cái đáp án sang token ID tương ứng để tính xác suất
def get_letter_to_ids(tokenizer, choices="ABCDEFGHIJKLMNOPQRSTUVWXYZ"):
    letter_to_ids = {l: [] for l in choices}
    vocab = tokenizer.get_vocab()
    for token_str, token_id in vocab.items():
        clean_token = token_str.replace(' ', '').replace('Ġ', '').replace('\n', '').replace('<0x0A>', '').strip()
        if len(clean_token) == 1 and clean_token.upper() in choices:
            letter_to_ids[clean_token.upper()].append(token_id)
            
    for char in choices:
        for prefix in ["", " ", "\n"]:
            for c in [char, char.lower()]:
                tids = tokenizer.encode(prefix + c, add_special_tokens=False)
                if tids:
                    tid = tids[-1]
                    if tid not in letter_to_ids[char]:
                        letter_to_ids[char].append(tid)
    return letter_to_ids

# Cách 1: Tính Log-Likelihood của hậu tố (suffix) dựa trên ngữ cảnh chung (prompt) dùng KV Cache (Bản Batched Tối Ưu Tốc Độ)
def get_suffix_likelihoods_kv_cache_batched(model, processor, prompt_text, suffixes, device):
    C = len(suffixes)
    
    # 1. Tokenize prefix
    inputs_q = processor(text=prompt_text, return_tensors="pt").to(device)
    input_ids_q = inputs_q.input_ids
    attention_mask_q = inputs_q.attention_mask
    prompt_len = input_ids_q.shape[-1]
    
    # 2. Tokenize suffixes (dùng left padding cho batch)
    processor.tokenizer.padding_side = "left"
    inputs_s = processor(text=suffixes, padding=True, return_tensors="pt").to(device)
    input_ids_s = inputs_s.input_ids
    attention_mask_s = inputs_s.attention_mask
    suffix_len = input_ids_s.shape[-1]
    
    position_ids_q = torch.arange(prompt_len, dtype=torch.long, device=device).unsqueeze(0)
    
    # Tính toán position_ids cho các suffix có left padding
    cum_sum = torch.cumsum(attention_mask_s, dim=-1)
    position_ids_s = (prompt_len + cum_sum - 1) * attention_mask_s
    
    with torch.inference_mode():
        # Bước 1: Chạy forward pass phần chung để lấy KV Cache
        past_key_values = DynamicCache()
        outputs_q = model(
            input_ids=input_ids_q,
            attention_mask=attention_mask_q,
            position_ids=position_ids_q,
            past_key_values=past_key_values,
            use_cache=True
        )
        
        # Bước 2: Nhân bản KV Cache C lần trên GPU
        batched_cache = DynamicCache()
        batched_cache._seen_tokens = past_key_values.get_seq_length()
        for layer_idx in range(len(past_key_values.key_cache)):
            k = past_key_values.key_cache[layer_idx]
            v = past_key_values.value_cache[layer_idx]
            batched_cache.key_cache.append(k.repeat(C, 1, 1, 1))
            batched_cache.value_cache.append(v.repeat(C, 1, 1, 1))
            
        # Bước 3: Chạy forward pass cho các suffix song song (Batched)
        new_attention_mask = torch.cat([
            attention_mask_q.repeat(C, 1),
            attention_mask_s
        ], dim=-1)
        
        outputs_s = model(
            input_ids=input_ids_s,
            attention_mask=new_attention_mask,
            position_ids=position_ids_s,
            past_key_values=batched_cache,
            use_cache=True
        )
        suffix_logits = outputs_s.logits
        
    # Bước 4: Trích xuất log-probabilities
    prompt_logits = outputs_q.logits[:, -1:, :].repeat(C, 1, 1)
    eval_logits = torch.cat([prompt_logits, suffix_logits[:, :-1, :]], dim=1)
    log_probs = torch.log_softmax(eval_logits, dim=-1)
    
    target_log_probs = torch.gather(log_probs, dim=-1, index=input_ids_s.unsqueeze(-1)).squeeze(-1)
    target_log_probs = target_log_probs * attention_mask_s
    
    scores = []
    for i in range(C):
        num_tokens = attention_mask_s[i].sum().item()
        total_log_prob = target_log_probs[i].sum().item()
        score = total_log_prob / (num_tokens + 1e-5)
        scores.append(score)
        
    return scores

# =====================================================
# HÀM CHẠY KNOWLEDGE SỬ DỤNG LIKELIHOOD & RETRY FALLBACK
# =====================================================
def run_knowledge_generation(question_items, model, device, processor):
    if not question_items: return {}
    
    def process_batch(batch):
        preds = {}
        batch_prompts = []
        
        for item in batch:
            choices_text = "\n".join(f"{LETTERS[k]}. {choice}" for k, choice in enumerate(item["choices"]))
            user_prompt = f"Câu hỏi:\n{item['question']}\n\nLựa chọn:\n{choices_text}\n\nNhiệm vụ: Chọn đúng 1 đáp án."
            messages = [
                {"role": "system", "content": [{"type": "text", "text": SYSTEM_KNOWLEDGE}]},
                {"role": "user", "content": [{"type": "text", "text": user_prompt}]}
            ]
            prompt_text = processor.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
            batch_prompts.append(prompt_text + "Đáp án:")
            
        inputs = processor(text=batch_prompts, padding=True, return_tensors="pt").to(device)
        with torch.inference_mode():
            outputs = model.generate(
                **inputs, 
                max_new_tokens=15, 
                do_sample=False, 
                use_cache=True,
                pad_token_id=processor.tokenizer.eos_token_id
            )
            
        for idx, item in enumerate(batch):
            decoded = processor.tokenizer.decode(outputs[idx][inputs.input_ids.shape[1]:], skip_special_tokens=True)
            raw = decoded.strip()
            
            # Extract first uppercase letter (A-J) from the generated text
            m = re.search(r"\b([A-Z])\b", raw.upper())
            if not m:
                m = re.search(r"([A-Z])", raw.upper())
                
            pred_letter = m.group(1) if m else "A"
            preds[item["qid"]] = {"pred": pred_letter, "raw": f"Generated: '{raw}' -> Selected: {pred_letter}"}
            
        if 'inputs' in locals(): del inputs
        if 'outputs' in locals(): del outputs
        
        return preds

    # Create dynamic batches for knowledge (to avoid CUDA OOM)
    batches = []
    current_batch = []
    current_max_len = 0
    max_tokens_limit = 2500
    
    for item in question_items:
        choices_text = "\n".join(item["choices"])
        estimated_len = (len(item["question"]) + len(choices_text)) // 3
        temp_max_len = max(current_max_len, estimated_len)
        temp_batch_size = len(current_batch) + 1
        
        if (temp_batch_size * temp_max_len > max_tokens_limit or temp_batch_size > 8) and current_batch:
            batches.append(current_batch)
            current_batch = [item]
            current_max_len = estimated_len
        else:
            current_batch.append(item)
            current_max_len = temp_max_len
            
    if current_batch:
        batches.append(current_batch)
        
    results = {}
    
    def process_batch_with_fallback(batch):
        try:
            return process_batch(batch)
        except (torch.cuda.OutOfMemoryError, RuntimeError) as e:
            if isinstance(e, RuntimeError) and "out of memory" not in str(e).lower():
                raise e
            print(f"⚠️ [OOM] Hết bộ nhớ khi sinh batch size {len(batch)} cho Knowledge. Đang tự động chia đôi...")
            torch.cuda.empty_cache()
            gc.collect()
            
            if len(batch) <= 1:
                print(f"❌ [OOM Critical] Lỗi bộ nhớ trên câu Knowledge {batch[0]['qid']}! Gán đáp án mặc định A.")
                return {batch[0]["qid"]: {"pred": "A", "raw": "OutOfMemoryError fallback default A"}}
                
            mid = len(batch) // 2
            res1 = process_batch_with_fallback(batch[:mid])
            res2 = process_batch_with_fallback(batch[mid:])
            res1.update(res2)
            return res1

    for batch in batches:
        results.update(process_batch_with_fallback(batch))
        
    return results


# =====================================================
# HÀM CHẠY REASONING SỬ DỤNG LIKELIHOOD & RETRY FALLBACK
# =====================================================
def run_reasoning_likelihood(question_items, max_new_tokens, model, device, processor):
    if not question_items: return {}
    
    letter_to_ids = get_letter_to_ids(processor.tokenizer, LETTERS)
    
    def process_batch(batch):
        preds = {}
        batch_prompts = []
        batch_prompts_dummy = []
        
        for item in batch:
            choices_text = "\n".join(f"{LETTERS[k]}. {choice}" for k, choice in enumerate(item["choices"]))
            
            # Step 1: user prompt to generate reasoning
            user_prompt = f"Câu hỏi:\n{item['question']}\n\nLựa chọn:\n{choices_text}\n\nNhiệm vụ: Chọn đúng 1 đáp án."
            
            messages = [
                {"role": "system", "content": [{"type": "text", "text": SYSTEM_REASONING}]},
                {"role": "user", "content": [{"type": "text", "text": user_prompt}]}
            ]
            prompt_text = processor.apply_chat_template(messages, tokenize=False, add_generation_prompt=True) + "Suy luận:\n"
            batch_prompts.append(prompt_text)
            
            if USE_CALIBRATION:
                dummy_prompt = f"Câu hỏi:\nN/A\n\nLựa chọn:\n{choices_text}\n\nNhiệm vụ: Chọn đúng 1 đáp án."
                messages_dummy = [
                    {"role": "system", "content": [{"type": "text", "text": SYSTEM_REASONING}]},
                    {"role": "user", "content": [{"type": "text", "text": dummy_prompt}]}
                ]
                prompt_text_dummy = processor.apply_chat_template(messages_dummy, tokenize=False, add_generation_prompt=True) + "Suy luận:\n"
                batch_prompts_dummy.append(prompt_text_dummy)
                
        # --- BƯỚC 1: SINH SUY LUẬN (BATCHED GENERATION) ---
        inputs = processor(text=batch_prompts, padding=True, return_tensors="pt").to(device)
        with torch.inference_mode():
            outputs_step1 = model.generate(
                **inputs, max_new_tokens=max_new_tokens, do_sample=False, use_cache=True, pad_token_id=processor.tokenizer.eos_token_id
            )
            
        reasoning_texts = []
        for idx in range(len(batch)):
            decoded = processor.tokenizer.decode(outputs_step1[idx][inputs.input_ids.shape[1]:], skip_special_tokens=True)
            reasoning_texts.append(decoded.strip())
            
        # Giải phóng bộ nhớ Step 1
        if 'inputs' in locals(): del inputs
        if 'outputs_step1' in locals(): del outputs_step1
        
        # --- BƯỚC 2: ÉP CHỐT ĐÁP ÁN ---
        if USE_SINGLE_PASS:
            forced_texts = []
            forced_texts_dummy = []
            for idx, item in enumerate(batch):
                full_context = batch_prompts[idx] + reasoning_texts[idx] + "\n\nVậy đáp án đúng là:"
                forced_texts.append(full_context)
                
                if USE_CALIBRATION:
                    full_context_dummy = batch_prompts_dummy[idx] + "[N/A]" + "\n\nVậy đáp án đúng là:"
                    forced_texts_dummy.append(full_context_dummy)
                    
            inputs_step2 = processor(text=forced_texts, padding=True, return_tensors="pt").to(device)
            with torch.inference_mode():
                outputs_step2 = model(**inputs_step2)
                logits_step2 = outputs_step2.logits[:, -1, :]
            probs_step2 = torch.softmax(logits_step2, dim=-1)
            
            if USE_CALIBRATION:
                inputs_step2_dummy = processor(text=forced_texts_dummy, padding=True, return_tensors="pt").to(device)
                with torch.inference_mode():
                    outputs_step2_dummy = model(**inputs_step2_dummy)
                    logits_step2_dummy = outputs_step2_dummy.logits[:, -1, :]
                probs_step2_dummy = torch.softmax(logits_step2_dummy, dim=-1)
                
            for idx, item in enumerate(batch):
                choice_probs = {}
                active_letters = LETTERS[:len(item["choices"])]
                for char in active_letters:
                    tids = letter_to_ids[char]
                    score = probs_step2[idx, tids].sum().item() if tids else 0.0
                    
                    if USE_CALIBRATION:
                        score_dummy = probs_step2_dummy[idx, tids].sum().item() if tids else 0.0
                        score = score / (score_dummy + 1e-5)
                        
                    choice_probs[char] = score
                    
                total_prob = sum(choice_probs.values())
                if total_prob > 0:
                    choice_probs = {k: v / total_prob for k, v in choice_probs.items()}
                    
                best_letter = max(choice_probs, key=choice_probs.get)
                best_letter = normalize_prediction(best_letter, item)
                probs_str = ", ".join(f"{k}: {v:.1%}" for k, v in choice_probs.items())
                raw_combined = reasoning_texts[idx] + f"\n\n[ÉP CHỐT LIKELIHOOD]: {best_letter} ({probs_str})"
                preds[item["qid"]] = {"pred": best_letter, "raw": raw_combined}
                
            if 'inputs_step2' in locals(): del inputs_step2
            if 'outputs_step2' in locals(): del outputs_step2
            if 'inputs_step2_dummy' in locals(): del inputs_step2_dummy
            if 'outputs_step2_dummy' in locals(): del outputs_step2_dummy
            
        else:
            for idx, item in enumerate(batch):
                full_context = batch_prompts[idx] + reasoning_texts[idx] + "\n\nVậy đáp án đúng là:"
                active_letters = LETTERS[:len(item["choices"])]
                suffixes = [f" {l}" for l in active_letters]
                
                scores = get_suffix_likelihoods_kv_cache_batched(model, processor, full_context, suffixes, device)
                
                if USE_CALIBRATION:
                    full_context_dummy = batch_prompts_dummy[idx] + "[N/A]" + "\n\nVậy đáp án đúng là:"
                    scores_dummy = get_suffix_likelihoods_kv_cache_batched(model, processor, full_context_dummy, suffixes, device)
                    calibrated_scores = [s - sd for s, sd in zip(scores, scores_dummy)]
                else:
                    calibrated_scores = scores
                    
                best_idx = calibrated_scores.index(max(calibrated_scores))
                best_letter = active_letters[best_idx]
                best_letter = normalize_prediction(best_letter, item)
                
                exp_scores = []
                for s in calibrated_scores:
                    try:
                        exp_scores.append(math.exp(s))
                    except OverflowError:
                        exp_scores.append(float('inf'))
                sum_exp = sum(exp_scores)
                if sum_exp > 0:
                    probs_lh = [e / sum_exp for e in exp_scores]
                else:
                    probs_lh = [1.0 / len(calibrated_scores)] * len(calibrated_scores)
                    
                probs_str = ", ".join(f"{active_letters[k]}: {probs_lh[k]:.1%}" for k in range(len(active_letters)))
                raw_combined = reasoning_texts[idx] + f"\n\n[ÉP CHỐT LIKELIHOOD]: {best_letter} ({probs_str})"
                preds[item["qid"]] = {"pred": best_letter, "raw": raw_combined}
                
        return preds

    # Tạo batch động cho reasoning (Giới hạn tối đa batch size 2 do sinh chuỗi dài)
    batches = []
    current_batch = []
    current_max_len = 0
    max_tokens_limit = 2400
    
    for item in question_items:
        choices_text = "\n".join(item["choices"])
        estimated_len = (len(item["question"]) + len(choices_text)) // 3
        temp_max_len = max(current_max_len, estimated_len)
        temp_batch_size = len(current_batch) + 1
        
        if (temp_batch_size * temp_max_len > max_tokens_limit or temp_batch_size > 4) and current_batch:
            batches.append(current_batch)
            current_batch = [item]
            current_max_len = estimated_len
        else:
            current_batch.append(item)
            current_max_len = temp_max_len
            
    if current_batch:
        batches.append(current_batch)
        
    results = {}
    
    def process_batch_with_fallback(batch):
        try:
            return process_batch(batch)
        except (torch.cuda.OutOfMemoryError, RuntimeError) as e:
            if isinstance(e, RuntimeError) and "out of memory" not in str(e).lower():
                raise e
            print(f"⚠️ [OOM] Hết bộ nhớ khi chạy Reasoning batch size {len(batch)}. Đang tự động chia đôi...")
            torch.cuda.empty_cache()
            gc.collect()
            
            if len(batch) <= 1:
                print(f"❌ [OOM Critical] Lỗi bộ nhớ nghiêm trọng trên câu Reasoning {batch[0]['qid']}! Đặt đáp án mặc định A.")
                return {batch[0]["qid"]: {"pred": "A", "raw": "OutOfMemoryError reasoning fallback default A"}}
                
            mid = len(batch) // 2
            res1 = process_batch_with_fallback(batch[:mid])
            res2 = process_batch_with_fallback(batch[mid:])
            res1.update(res2)
            return res1

    for batch in batches:
        results.update(process_batch_with_fallback(batch))
        
    return results

# =====================================================
# TRÌNH QUẢN LÝ ĐA LUỒNG CHO PHƯƠNG PHÁP MỚI
# =====================================================
def run_batch_likelihood(question_items, mode, max_new_tokens):
    if not question_items: return {}

    num_workers = len(models)
    chunk_size = (len(question_items) + num_workers - 1) // num_workers
    chunks = [question_items[i:i + chunk_size] for i in range(0, len(question_items), chunk_size)]
    
    results = {}
    
    with ThreadPoolExecutor(max_workers=num_workers) as executor:
        futures = []
        for i, chunk in enumerate(chunks):
            if chunk:
                target_model = models[i % num_workers]
                target_device = devices[i % num_workers]
                target_processor = processors[i % num_workers]
                
                if mode == "KNOWLEDGE":
                    futures.append(executor.submit(run_knowledge_generation, chunk, target_model, target_device, target_processor))
                else:
                    futures.append(executor.submit(run_reasoning_likelihood, chunk, max_new_tokens, target_model, target_device, target_processor))
                
        for future in futures:
            results.update(future.result())
            
    return results

# =====================================================
# THỰC THI PHƯƠNG PHÁP MỚI & HIỂN THỊ
# =====================================================
results_lh = {}

print(f"\n[1/2] Đang xử lý {len(knowledge_questions)} câu hỏi thường (Likelihood)...")
if knowledge_questions:
    results_lh.update(run_batch_likelihood(knowledge_questions, mode="KNOWLEDGE", max_new_tokens=1))

print(f"\n[2/2] Đang xử lý {len(reasoning_questions)} câu hỏi 'là bao nhiêu' (Likelihood + Reasoning)...")
if reasoning_questions:
    results_lh.update(run_batch_likelihood(reasoning_questions, mode="REASONING", max_new_tokens=300))

# =====================================================
# HIỂN THỊ KẾT QUẢ ĐÁNH GIÁ
# =====================================================
print("\n" + "=" * 100)
print("MODEL OUTPUT (LIKELIHOOD METHOD)")
print("=" * 100)

for item in questions:
    qid = item["qid"]
    mode = "REASONING" if is_reasoning_question(item) else "KNOWLEDGE"
    res = results_lh.get(qid, {"pred": "?", "raw": "NO OUTPUT"})
    
    print(f"QID   : {qid}")
    print(f"MODE  : {mode}")
    print(f"RAW   :\n{res['raw']}")
    print(f"PRED  : {res['pred']}")
    print("-" * 100)

correct_lh = 0
total_evaluated_lh = 0
print("\n" + "=" * 100 + "\nEVALUATION (LIKELIHOOD METHOD)\n" + "=" * 100)
for item in questions:
    qid = item["qid"]
    if qid in GROUND_TRUTH:
        gt = GROUND_TRUTH[qid]
        pred = results_lh.get(qid, {}).get("pred", "?")
        ok = pred == gt
        if ok:
            correct_lh += 1
        total_evaluated_lh += 1
        print(f"{qid:12s} | Pred={pred:2s} | GT={gt:2s} | {'✓' if ok else '✗'}")

print("=" * 100)
if total_evaluated_lh > 0:
    print(f"Correct : {correct_lh}/{total_evaluated_lh}\nAccuracy: {correct_lh / total_evaluated_lh:.2%}")
else:
    print("No questions with ground truth were evaluated.")
print("=" * 100)
# Out:
# [1/2] Đang xử lý 170 câu hỏi thường (Likelihood)...
#
# [2/2] Đang xử lý 93 câu hỏi 'là bao nhiêu' (Likelihood + Reasoning)...
#
# ====================================================================================================
# MODEL OUTPUT (LIKELIHOOD METHOD)
# ====================================================================================================
# QID   : test_0201
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B. Algarve
#
# Giải thích:
# Theo đoạn văn, trong phần' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0202
# MODE  : REASONING
# RAW   :
# Theo định luật thứ ba Kepler, bình phương chu kỳ quỹ đạo tỉ lệ với lập phương bán kính quỹ đạo: $T^2 \propto r^3$.
# Trạng thái cộng hưởng 3:2 có nghĩa là $T_1 / T_2 = 2/3$ (mặt trong quay nhanh hơn).
# Thay vào công thức: $(T_1/T_2)^2 = (r_1/r_2)^3 \Rightarrow (2/3)^2 = (r_1/r_2)^3 \Rightarrow 4/9 = (r_1/r_2)^3$.
# Vậy đáp án đúng là D.
# </think>
#
# Suy luận:
# Theo định luật Kepler thứ ba: $T^2 \propto r^3$.
# Cộng hưởng 3:2 nghĩa là $T_1/T_2 = 2/3$.
# Thay vào: $(T_1/T_2)^2 = (r_1/r_2)^3 \Rightarrow (2/3)^2 = (r_1/r_2)^3 \Rightarrow 4/9 = (r_1/r_2)^3$.
# Vậy đáp án đúng là D.
#
# [ÉP CHỐT LIKELIHOOD]: D (A: 0.0%, B: 0.0%, C: 0.0%, D: 99.9%, E: 0.0%, F: 0.0%, G: 0.0%, H: 0.0%, I: 0.0%, J: 0.0%)
# PRED  : D
# ----------------------------------------------------------------------------------------------------
# QID   : test_0203
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B. Tổ hợp các thái độ và thuộc tính riêng của cá nhân.' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0204
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A. Tiếng Việt có sự phân biệt rõ ràng giữa các âm điệu (' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0205
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B.
#
# Giải thích:
# Theo đoạn văn: "Linh lăng' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0206
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'D. Tất cả các phương án trên.
#
# Giải thích: Hệ thống' -> Selected: D
# PRED  : D
# ----------------------------------------------------------------------------------------------------
# QID   : test_0207
# MODE  : REASONING
# RAW   :
# 1. Hàm cầu thị trường: $Q = a - P \Rightarrow P = a - Q$.
# 2. Tổng sản lượng $Q = q_1 + q_2$. Do đó, hàm cầu của doanh nghiệp 1 là $P = a - (q_1 + q_2)$.
# 3. Lợi nhuận của doanh nghiệp 1: $\pi_1 = (P - c)q_1 = (a - q_1 - q_2 - c)q_1$.
# 4. Điều kiện tối ưu hóa (đạo hàm theo $q_1$ bằng 0): $\frac{\partial \pi_1}{\partial q_1} = a - 2q_1 - q_2 - c = 0 \Rightarrow q_1 = \frac{a - c - q_2}{2}$.
# 5. Đối xứng: $q_1 = q_2 = q^*$. Thay vào phương trình: $q^* = \frac{a - c - q^*}{2} \Rightarrow 2q^* = a - c - q^* \Rightarrow 3q^* = a - c \Rightarrow q^* = \frac{a - c}{3}$.
# Vậy đáp án đúng là B.
# </think>
#
# Suy luận:
# Hàm lợi nhuận của doanh nghiệp 1 là $\pi_1 = (a - q_
#
# [ÉP CHỐT LIKELIHOOD]: B (A: 0.1%, B: 98.1%, C: 0.1%, D: 0.1%, E: 0.4%, F: 0.0%, G: 0.5%, H: 0.4%, I: 0.1%, J: 0.1%)
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0208
# MODE  : REASONING
# RAW   :
# Công thức Rutherford: $\frac{d\sigma}{d\Omega} \propto \frac{1}{E} \left( \frac{Z_1 Z_2 e^2}{4 \pi \epsilon_0} \right)^2 \frac{1}{\sin^4(\theta/2)}$.
# Khi $Z_1$ tăng gấp đôi ($Z_1' = 2Z_1$), các tham số khác không đổi.
# Tiết diện vi phân mới $\frac{d\sigma'}{d\Omega} \propto (2Z_1)^2 = 4Z_1^2$.
# Do đó, tiết diện vi phân thay đổi theo nhân tử 4.
# Vậy đáp án đúng là B.
# </think>
#
# Suy luận:
# Công thức Rutherford cho thấy $\frac{d\sigma}{d\Omega} \propto (Z_1 Z_2)^2$. Khi $Z_1$ tăng gấp đôi ($2Z_1$), hệ số tỉ lệ sẽ thay đổi theo $(2Z_1)^2 = 4Z_1^2$.
# Vậy tiết diện vi phân tăng lên 4 lần.
# Vậy đáp án đúng là B.
#
# [ÉP CHỐT LIKELIHOOD]: B (A: 0.0%, B: 99.8%, C: 0.0%, D: 0.0%, E: 0.0%, F: 0.0%, G: 0.1%, H: 0.1%, I: 0.0%, J: 0.0%)
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0209
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A.
#
# Giải thích:
# - Bình đẳng về quyền và nghĩa vụ' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0210
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B.
#
# Giải thích:
# Theo phần "II. Ý nghĩa tên' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0211
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A. Đồng
#
# Giải thích:
# - Trong phần "3. The' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0212
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A. Perkins (chủ tịch Ngân hàng Xấu xa)
#
# Giải' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0213
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'D.
#
# Giải thích: Khi một khe bị làm mờ (cường' -> Selected: D
# PRED  : D
# ----------------------------------------------------------------------------------------------------
# QID   : test_0214
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B.
#
# Giải thích:
# - Australia: 18,7' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0215
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A. Tính hiện thực và sáng tạo.
#
# Giải thích: Khi cách' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0216
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B.
#
# Giải thích: Các bước tiến công nghệ trong giao thông,' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0217
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B. Desa.
#
# Giải thích:
# - Đoạn văn trong phần "' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0218
# MODE  : REASONING
# RAW   :
# Biến đổi Laplace của $e^{-at}\cos(\omega t)$ là $\frac{s+a}{(s+a)^2 + \omega^2}$.
# Với $a=3, \omega=4$, ta có $F(s) = \frac{s+3}{(s+3)^2 + 16}$.
# So sánh với các lựa chọn, đáp án A khớp.
#
# Vậy đáp án đúng là A.
# </think>
#
# Suy luận:
# Biến đổi Laplace của $e^{-at}\cos(\omega t)$ là $\frac{s+a}{(s+a)^2 + \omega^2}$.
# Với $a=3, \omega=4$, ta có $F(s) = \frac{s+3}{(s+3)^2 + 16}$.
# So sánh với các lựa chọn, đáp án A khớp.
#
# Vậy đáp án đúng là A.
#
# [ÉP CHỐT LIKELIHOOD]: A (A: 98.5%, B: 0.1%, C: 0.1%, D: 0.1%, E: 0.2%, F: 0.1%, G: 0.4%, H: 0.4%, I: 0.1%, J: 0.1%)
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0219
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B.
#
# Giải thích:
# Theo đoạn văn, mục "II.' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0220
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'J.
#
# Giải thích:
# 1.  **Về thuế doanh nghiệp' -> Selected: J
# PRED  : J
# ----------------------------------------------------------------------------------------------------
# QID   : test_0221
# MODE  : REASONING
# RAW   :
# Tính lượng cầu tại P=5: Qd1 = 100 - 5*5 = 75.
# Tính lượng cầu tại P=7: Qd2 = 100 - 5*7 = 65.
# Thay đổi lượng cầu: Qd2 - Qd1 = 65 - 75 = -10 (giảm 10 đơn vị).
# Vậy đáp án đúng là A.
# </think>
#
# Suy luận:
# Tính lượng cầu tại P=5: Qd1 = 100 - 5*5 = 75.
# Tính lượng cầu tại P=7: Qd2 = 100 - 5*7 = 65.
# Thay đổi lượng cầu: Qd2 - Qd1 = 65 - 75 = -10 (giảm 10 đơn vị).
# Vậy đáp án đúng là A.
#
# [ÉP CHỐT LIKELIHOOD]: A (A: 99.9%, B: 0.0%, C: 0.0%, D: 0.0%)
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0222
# MODE  : REASONING
# RAW   :
# Áp dụng định luật Ba về chuyển động hành tinh: $T^2 \propto R^3$.
# Với hành tinh 1: $T_1 = 1$ năm, $R_1 = 1$ AU.
# Với hành tinh 2: $R_2 = 4$ AU, cần tìm $T_2$.
# Theo công thức: $(T_2/T_1)^2 = (R_2/R_1)^3 \Rightarrow (T_2/1)^2 = (4/1)^3 = 64$.
# Suy ra $T_2^2 = 64 \Rightarrow T_2 = 8$ năm.
# Vậy đáp án đúng là G (hoặc J).
#
# Chốt lại đáp án: G.
# </think>
#
# Suy luận:
# Áp dụng định luật Ba về chuyển động hành tinh: $T^2 \propto R^3$.
# Với hành tinh 1: $T_1 = 1$ năm, $R_1 = 1$ AU.
# Với hành tinh 2: $R_2 = 4$ AU, cần tìm $T_2$.
# Theo công thức: $(T_2/T_1)^2 = (R_2/R_1)^3 \Rightarrow (T_2/1)^2 = (4/1)^3 = 64$.
# Suy ra $T_
#
# [ÉP CHỐT LIKELIHOOD]: G (A: 0.0%, B: 0.0%, C: 0.0%, D: 0.0%, E: 0.0%, F: 0.0%, G: 99.6%, H: 0.2%, I: 0.0%, J: 0.1%)
# PRED  : G
# ----------------------------------------------------------------------------------------------------
# QID   : test_0223
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'H.
#
# Giải thích:
# - A: Thuế cố định không giải' -> Selected: H
# PRED  : H
# ----------------------------------------------------------------------------------------------------
# QID   : test_0224
# MODE  : REASONING
# RAW   :
# 1. Theo thông tin chính thức từ UBND tỉnh Gia Lai và các báo cáo thống kê năm 2025, sau khi thực hiện sắp xếp, sáp nhập các đơn vị hành chính cấp xã, tổng số đơn vị hành chính cấp xã (bao gồm xã, phường, thị trấn) của tỉnh Gia Lai là 135 đơn vị.
# 2. Con số này thay đổi so với các năm trước do quy hoạch sáp nhập các xã nhỏ thành các xã lớn hơn để tối ưu hóa quản lý.
# 3. So sánh với các lựa chọn: A. 130, B. 135, C. 140, D. 150.
# 4. Con số 135 khớp với thông tin thực tế.
#
# Vậy đáp án đúng là B.
# </think>
#
# Suy luận:
# Theo thông tin chính thức từ UBND tỉnh Gia Lai và các báo cáo thống kê năm 2025, sau khi thực hiện sắp xếp, sáp nhập các đơn vị hành chính cấp xã, tổng số đơn vị hành chính cấp xã (bao gồm xã, phường, thị trấn) của tỉnh Gia Lai là 135 đơn vị.
# So sánh với các lựa chọn: A. 130, B. 135, C. 140, D. 150.
# Con số 135 khớp với thông tin thực tế.
#
# Vậy đáp án đúng
#
# [ÉP CHỐT LIKELIHOOD]: B (A: 0.0%, B: 100.0%, C: 0.0%, D: 0.0%)
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0225
# MODE  : REASONING
# RAW   :
# Thể tích nước trong bể hình trụ là $V = \pi r^2 h$.
# Việc lấy đạo hàm theo thời gian: $\frac{dV}{dt} = \pi r^2 \frac{dh}{dt}$.
# Thay số: $10 = \pi (3)^2 \frac{dh}{dt} \Rightarrow 10 = 9\pi \frac{dh}{dt}$.
# Tính $\frac{dh}{dt} = \frac{10}{9\pi} \approx \frac{10}{28.27} \approx 0.3536$ m/phút.
# Làm tròn đến hai chữ số thập phân là 0.35 m/phút.
# Vậy đáp án đúng là C.
# </think>
#
# Suy luận:
# Thể tích nước trong bể hình trụ là $V = \pi r^2 h$. Lấy đạo hàm theo thời gian: $\frac{dV}{dt} = \pi r^2 \frac{dh}{dt}$.
# Thay số: $10 = \pi (3)^2 \frac{dh}{dt} \Rightarrow 10 = 9\pi \frac{dh}{dt}$.
# Tính $\frac{dh}{dt} = \frac{10}{9\pi} \approx 0.3536$ m/phút.
# Vậy đáp án đúng là
#
# [ÉP CHỐT LIKELIHOOD]: C (A: 0.0%, B: 0.0%, C: 99.1%, D: 0.0%, E: 0.1%, F: 0.1%, G: 0.3%, H: 0.2%, I: 0.0%, J: 0.0%)
# PRED  : C
# ----------------------------------------------------------------------------------------------------
# QID   : test_0226
# MODE  : REASONING
# RAW   :
# Đạo hàm của hàm số dạng $g(x) = \ln(u(x))$ theo quy tắc chuỗi là $g'(x) = \frac{u'(x)}{u(x)}$.
# Ở đây $u(x) = 5x^3 - 2x + 1$, nên $u'(x) = 15x^2 - 2$.
# Thay vào công thức: $g'(x) = \frac{15x^2 - 2}{5x^3 - 2x + 1}$.
# So sánh với các lựa chọn, đáp án A khớp chính xác.
#
# Đáp án: A
# </think>
#
# Suy luận:
# Áp dụng quy tắc đạo hàm hàm logarit: $[\ln(u)]' = \frac{u'}{u}$.
# Với $u = 5x^3 - 2x + 1 \Rightarrow u' = 15x^2 - 2$.
# Thay vào: $g'(x) = \frac{15x^2 - 2}{5x^3 - 2x + 1}$.
# Vậy đáp án đúng là A.
#
# [ÉP CHỐT LIKELIHOOD]: A (A: 99.6%, B: 0.0%, C: 0.0%, D: 0.0%, E: 0.1%, F: 0.0%, G: 0.1%, H: 0.1%, I: 0.0%, J: 0.0%)
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0227
# MODE  : REASONING
# RAW   :
# Tỷ số hiện hành = Vốn lưu động / Nợ ngắn hạn.
# Thay số: 1,5 = Vốn lưu động / 30.000.
# Tính toán: Vốn lưu động = 1,5 * 30.000 = 45.000 đô la.
# Vậy đáp án đúng là D.
# </think>
#
# Suy luận:
# Tỷ số hiện hành = Vốn lưu động / Nợ ngắn hạn.
# Thay số: 1,5 = Vốn lưu động / 30.000.
# Tính toán: Vốn lưu động = 1,5 * 30.000 = 45.000 đô la.
# Vậy đáp án đúng là D.
#
# [ÉP CHỐT LIKELIHOOD]: D (A: 0.0%, B: 0.0%, C: 0.0%, D: 100.0%)
# PRED  : D
# ----------------------------------------------------------------------------------------------------
# QID   : test_0228
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'G. Thiên tai tự nhiên.
#
# Giải thích:
# - Các yếu' -> Selected: G
# PRED  : G
# ----------------------------------------------------------------------------------------------------
# QID   : test_0229
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'C. Nhân cách.
#
# Chủ tịch Hồ Chí Minh đã xác định rõ' -> Selected: C
# PRED  : C
# ----------------------------------------------------------------------------------------------------
# QID   : test_0230
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'C. Chế độ chính trị.
#
# Xê-nô-phôn (' -> Selected: C
# PRED  : C
# ----------------------------------------------------------------------------------------------------
# QID   : test_0231
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B.
#
# Giải thích:
# - Theo Document 1: "Lo' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0232
# MODE  : REASONING
# RAW   :
# Số cách chia 10 người thành 2 nhóm 5 người là tổ hợp chập 5 của 10, chia cho 2! vì hai nhóm không phân biệt thứ tự.
# Công thức: C(10, 5) / 2! = (10! / (5! * 5!)) / 2 = 252 / 2 = 126.
# Vậy đáp án đúng là A.
# </think>
#
# Suy luận:
# Số cách chia 10 người thành 2 nhóm 5 người là tổ hợp chập 5 của 10, chia cho 2! vì hai nhóm không phân biệt thứ tự.
# Công thức: C(10, 5) / 2! = (10! / (5! * 5!)) / 2 = 252 / 2 = 126.
# Vậy đáp án đúng là A.
#
# [ÉP CHỐT LIKELIHOOD]: A (A: 98.1%, B: 0.1%, C: 0.1%, D: 0.1%, E: 0.3%, F: 0.1%, G: 0.5%, H: 0.6%, I: 0.0%, J: 0.0%)
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0233
# MODE  : REASONING
# RAW   :
# Lợi nhuận ròng = Lợi nhuận gộp - Chi phí hoạt động (lao động, quản lý, lãi vay...).
# Thông tin chỉ cho biết Chi phí hàng hóa bán ra (COGS) và Lợi nhuận gộp.
# Không có dữ liệu về các chi phí hoạt động khác để tính lợi nhuận ròng.
# Vậy đáp án đúng là A.
# </think>
#
# Suy luận:
# Lợi nhuận ròng = Lợi nhuận gộp - Chi phí hoạt động (không phải COGS).
# Thông tin chưa cho chi phí hoạt động khác nên không tính được.
# Vậy đáp án đúng là A.
#
# [ÉP CHỐT LIKELIHOOD]: A (A: 98.7%, B: 0.4%, C: 0.5%, D: 0.4%)
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0234
# MODE  : REASONING
# RAW   :
# Enthalpy thay đổi chuẩn của phản ứng được tính bằng tổng enthalpy tạo thành của sản phẩm trừ tổng enthalpy tạo thành của chất tham gia: $\Delta H^\circ = \sum \Delta H_f^\circ(\text{sản phẩm}) - \sum \Delta H_f^\circ(\text{chất tham gia})$.
# Thay số: $\Delta H^\circ = \Delta H_f^\circ(\text{C}_2\text{H}_6) - [\Delta H_f^\circ(\text{C}_2\text{H}_4) + \Delta H_f^\circ(\text{H}_2)]$.
# Vì $\Delta H_f^\circ(\text{H}_2) = 0$, nên $\Delta H^\circ = -84 - 52 = -136 \text{ kJ/mol}$.
# Vậy đáp án đúng là A.
# </think>
#
# Suy luận:
# Enthalpy thay đổi chuẩn của phản ứng được tính bằng tổng enthalpy tạo thành của sản phẩm trừ tổng enthalpy tạo thành của chất tham gia: $\Delta H^\circ = \sum \Delta H_f^\circ(\text{sản phẩm}) - \sum \Delta H_f^\circ(\text{chất tham gia})$.
# Thay số: $\Delta H^\circ = \Delta H_f^\circ(\text{C}_2\text{H}_6) -
#
# [ÉP CHỐT LIKELIHOOD]: A (A: 92.6%, B: 0.4%, C: 0.2%, D: 3.8%, E: 0.5%, F: 0.6%, G: 0.0%, H: 0.9%, I: 0.2%, J: 0.7%)
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0235
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B.
#
# Giải thích:
# Sự trùng hợp nhu cầu đôi (double' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0236
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A. Cho phép người dùng truy cập từ xa vào mạng cục bộ.' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0237
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A. Con đường cách mạng bạo lực.
#
# Tư tưởng của Chủ' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0238
# MODE  : REASONING
# RAW   :
# Chu kỳ con lắc đơn là $T = 2\pi\sqrt{\frac{L}{g}}$. Khi $g$ tăng lên $4g$, chu kỳ mới $T' = 2\pi\sqrt{\frac{L}{4g}} = \frac{1}{2} \cdot 2\pi\sqrt{\frac{L}{g}} = \frac{T}{2}$.
# Vậy đáp án đúng là B.
# </think>
#
# Suy luận:
# Công thức chu kỳ con lắc đơn là $T = 2\pi\sqrt{\frac{L}{g}}$. Khi $g$ tăng lên $4g$, chu kỳ mới $T' = 2\pi\sqrt{\frac{L}{4g}} = \frac{1}{2} \cdot 2\pi\sqrt{\frac{L}{g}} = \frac{T}{2}$.
# Vậy đáp án đúng là B.
#
# [ÉP CHỐT LIKELIHOOD]: B (A: 0.0%, B: 99.7%, C: 0.0%, D: 0.0%, E: 0.0%, F: 0.0%, G: 0.0%, H: 0.2%, I: 0.0%, J: 0.0%)
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0239
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B. Ủ sau khi ngâm nước và để ráo.
#
# Giải thích:' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0240
# MODE  : REASONING
# RAW   :
# 1. Tính khấu hao lũy kế sau 3 năm: Khấu hao = (Chi phí ban đầu - Giá trị sổ sách cuối cùng) hoặc Khấu hao hàng năm = (Chi phí ban đầu - Giá trị cuối cùng theo kế hoạch) / Số năm. Tuy nhiên, đề bài cho "cơ sở khấu hao là 48.000 đô la" thường hiểu là tổng khấu hao được phép hoặc khấu hao lũy kế.
# 2. Cách tính giá trị sổ sách (Book Value): Giá trị sổ sách = Chi phí ban đầu - Khấu hao lũy kế.
#    Nếu cơ sở khấu hao là 48.000 đô la (tổng khấu hao được ghi nhận), thì Giá trị sổ sách = 58.000 - 48.000 = 10.000 đô la? Không, các đáp án không khớp.
#    Có thể hiểu "cơ sở khấu hao" là giá trị còn lại sau khi khấu hao hết? Hoặc là khấu hao hàng năm?
#    Thử cách tính khác: Khấu hao hàng năm = (58.000 - 48.000) / 3 = 10.000 / 3 = 3.333. Không hợp lý.
#    Thử cách tính: Giá trị sổ sách = Chi phí ban đầu - Khấu hao lũy kế.
#    Nếu "c
#
# [ÉP CHỐT LIKELIHOOD]: D (A: 8.8%, B: 21.6%, C: 32.7%, D: 36.9%)
# PRED  : D
# ----------------------------------------------------------------------------------------------------
# QID   : test_0241
# MODE  : REASONING
# RAW   :
# Giá trị kỳ vọng (EV) được tính bằng tổng của các kết quả có trọng số xác suất: EV = (P1 * R1) + (P2 * R2).
# Trong đó: P1 = 0.8 (xác suất thành công), R1 = 15%; P2 = 0.2 (xác suất thất bại), R2 = -10%.
# Tính toán: EV = (0.8 * 15%) + (0.2 * -10%) = 12% - 2% = 10%.
# Vậy đáp án đúng là D.
# </think>
#
# Giá trị kỳ vọng (EV) được tính bằng tổng của các kết quả có trọng số xác suất: EV = (P1 * R1) + (P2 * R2).
# Trong đó: P1 = 0.8 (xác suất thành công), R1 = 15%; P2 = 0.2 (xác suất thất bại), R2 = -10%.
# Tính toán: EV = (0.8 * 15%) + (0.2 * -10%) = 12% - 2% = 10%.
# Vậy đáp án đúng là D.
#
# [ÉP CHỐT LIKELIHOOD]: D (A: 0.1%, B: 0.0%, C: 0.0%, D: 99.9%)
# PRED  : D
# ----------------------------------------------------------------------------------------------------
# QID   : test_0242
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'Chủ nghĩa Mác-Lênin là nền tảng tư tưởng, là' -> Selected: C
# PRED  : C
# ----------------------------------------------------------------------------------------------------
# QID   : test_0243
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B.
#
# Giải thích:
# - Đoạn văn 4 ghi rõ:' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0244
# MODE  : REASONING
# RAW   :
# Chi phí ghi sổ ban đầu là 2.000.000 USD.
# Tổng số đơn vị khai thác được là 20.000.
# Số đơn vị đã khai thác là 10.000.
# Chi phí khấu hao theo phương pháp sản lượng = (Chi phí ghi sổ ban đầu / Tổng số đơn vị) * Số đơn vị đã khai thác.
# Chi phí khấu hao = (2.000.000 / 20.000) * 10.000 = 100 * 10.000 = 1.000.000 USD.
# Giá trị ghi sổ còn lại = Chi phí ban đầu - Chi phí khấu hao = 2.000.000 - 1.000.000 = 1.000.000 USD.
# Vậy đáp án đúng là A.
# </think>
#
# Suy luận:
# Chi phí khấu hao theo phương pháp sản lượng = (Tổng chi phí / Tổng số đơn vị) * Số đơn vị đã khai thác = (2.000.000 / 20.000) * 10.000 = 1.000.000 USD.
# Giá trị ghi sổ còn lại = Tổng chi phí - Chi phí khấu hao = 2.0
#
# [ÉP CHỐT LIKELIHOOD]: A (A: 99.0%, B: 0.3%, C: 0.4%, D: 0.2%)
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0245
# MODE  : REASONING
# RAW   :
# Hàm số $f(x) = \frac{x^2 - 9}{|x-3|} = \frac{(x-3)(x+3)}{|x-3|}$.
# Khi $x \to 3$, ta xét giới hạn trái và phải.
# Với $x \to 3^+$, $|x-3| = x-3$, nên $f(x) = \frac{(x-3)(x+3)}{x-3} = x+3 \to 6$.
# Với $x \to 3^-$, $|x-3| = -(x-3)$, nên $f(x) = \frac{(x-3)(x+3)}{-(x-3)} = -(x+3) \to -6$.
# Vì $\lim_{x \to 3^+} f(x) \neq \lim_{x \to 3^-} f(x)$, nên giới hạn không tồn tại.
# Vậy đáp án đúng là E.
# </think>
#
# Suy luận:
# Biến đổi hàm số: $f(x) = \frac{(x-3)(x+3)}{|x-3|}$.
# Xét giới hạn trái: $\lim_{x \to 3^-} f(x) = \lim_{x \to 3^-} \frac{(x-3)(x+3)}{-(x
#
# [ÉP CHỐT LIKELIHOOD]: E (A: 0.7%, B: 2.7%, C: 2.7%, D: 1.3%, E: 77.5%, F: 1.7%, G: 5.7%, H: 6.7%, I: 0.6%, J: 0.4%)
# PRED  : E
# ----------------------------------------------------------------------------------------------------
# QID   : test_0246
# MODE  : REASONING
# RAW   :
# Áp dụng định luật Raoult: $P_{dung dịch} = P_{tinh khiết} \times X_{dung môi}$.
# Thay số: $784 = 800 \times X_{dung môi}$.
# Tính toán: $X_{dung môi} = 784 / 800 = 0.98$.
# Vậy đáp án đúng là F.
# </think>
#
# Suy luận:
# Áp dụng định luật Raoult: $P_{dung dịch} = P_{tinh khiết} \times X_{dung môi}$.
# Thay số: $784 = 800 \times X_{dung môi}$.
# Tính toán: $X_{dung môi} = 784 / 800 = 0.98$.
# Vậy đáp án đúng là F.
#
# [ÉP CHỐT LIKELIHOOD]: F (A: 0.0%, B: 0.0%, C: 0.0%, D: 0.0%, E: 0.0%, F: 100.0%, G: 0.0%, H: 0.0%, I: 0.0%, J: 0.0%)
# PRED  : F
# ----------------------------------------------------------------------------------------------------
# QID   : test_0247
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'C. Chiếm hữu nô lệ.
#
# Giải thích: Trong lịch sử' -> Selected: C
# PRED  : C
# ----------------------------------------------------------------------------------------------------
# QID   : test_0248
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B. Hóa học thiên thể.
#
# Giải thích:
# - Đoạn văn' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0249
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B. Biobutanol.
#
# Giải thích:
# - Đoạn văn' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0250
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'D.
#
# Giải thích:
# Hàm sản xuất có hiệu suất không' -> Selected: D
# PRED  : D
# ----------------------------------------------------------------------------------------------------
# QID   : test_0251
# MODE  : REASONING
# RAW   :
# Phân tích số 36: $36 = 2^2 \times 3^2$.
# Các ước số dương của 36 là: 1, 2, 3, 4, 6, 9, 12, 18, 36.
# Tính tổng các ước số: $\sigma(36) = 1 + 2 + 3 + 4 + 6 + 9 + 12 + 18 + 36 = 91$.
# Hoặc dùng công thức: $\sigma(36) = \sigma(2^2)\sigma(3^2) = (1+2+4)(1+3+9) = 7 \times 13 = 91$.
# Vậy đáp án đúng là H.
# </think>
#
# Suy luận:
# Phân tích số 36: $36 = 2^2 \times 3^2$.
# Tính tổng các ước số bằng công thức: $\sigma(36) = \sigma(2^2)\sigma(3^2) = (1+2+4)(1+3+9) = 7 \times 13 = 91$.
# Vậy đáp án đúng là H.
#
# [ÉP CHỐT LIKELIHOOD]: H (A: 0.0%, B: 0.0%, C: 0.0%, D: 0.0%, E: 0.0%, F: 0.0%, G: 0.0%, H: 100.0%, I: 0.0%, J: 0.0%)
# PRED  : H
# ----------------------------------------------------------------------------------------------------
# QID   : test_0252
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'C. Xạ khuẩn.
#
# Giải thích:
# - Kháng sinh' -> Selected: C
# PRED  : C
# ----------------------------------------------------------------------------------------------------
# QID   : test_0253
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'D. Bảo vệ, hấp thụ, bài tiết.
#
# Giải thích:' -> Selected: D
# PRED  : D
# ----------------------------------------------------------------------------------------------------
# QID   : test_0254
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A. Xã Nhơn Hưng.
#
# Giải thích: Theo thông tin về việc' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0255
# MODE  : REASONING
# RAW   :
# 1. Khối lượng thứ nhất (AM1): Chỉ có thế năng đàn hồi ban đầu $E_{p1} = \frac{1}{2}kA^2$. Động năng cực đại $K_{max1} = E_{p1} = \frac{1}{2}kA^2$.
# 2. Khối lượng thứ hai (AM2): Có thế năng ban đầu $E_{p2} = \frac{1}{2}kA^2$ và động năng ban đầu $K_{0} = \frac{1}{2}mv_0^2$. Năng lượng cơ học toàn phần $E_{total2} = \frac{1}{2}kA^2 + \frac{1}{2}mv_0^2$. Động năng cực đại $K_{max2} = E_{total2} = \frac{1}{2}kA^2 + \frac{1}{2}mv_0^2$.
# 3. Tỉ số cần tìm: $\frac{K_{max2}}{K_{max1}} = \frac{\frac{1}{2}kA^2 + \frac{1}{2}mv_0^2}{\frac{1}{2}kA^2} = 1 + \frac{mv_0^2}{kA^2}$.
# 4. Thay $k = m\omega^2$
#
# [ÉP CHỐT LIKELIHOOD]: H (A: 0.0%, B: 0.1%, C: 0.4%, D: 5.5%, E: 0.3%, F: 1.5%, G: 4.8%, H: 45.5%, I: 40.0%, J: 1.8%)
# PRED  : H
# ----------------------------------------------------------------------------------------------------
# QID   : test_0256
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B. Co dãn hoàn toàn.
#
# Giải thích:
# - Khi' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0257
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A. Cuộc bầu cử Tổng thống Grover Cleveland.
#
# Giải thích:' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0258
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A. Thời kỳ thuộc địa đến những năm 1820.' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0259
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A. Sự phát triển mạnh mẽ với nhiều xu hướng khác nhau.' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0260
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B. Kinh tế.
#
# Giải thích: Các quy định về thuế và' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0261
# MODE  : REASONING
# RAW   :
# Số cạnh tối đa trong đồ thị vô hướng $n$ đỉnh là $\binom{n}{2} = \frac{n(n-1)}{2}$.
# Mỗi cạnh xuất hiện độc lập với xác suất $p = \frac{1}{3}$.
# Số cạnh kỳ vọng $E[X] = \text{số cạnh tối đa} \times p = \frac{n(n-1)}{2} \times \frac{1}{3} = \frac{n(n-1)}{6}$.
# Vậy đáp án đúng là B.
# </think>
#
# Suy luận:
# Số cạnh tối đa trong đồ thị vô hướng $n$ đỉnh là $\binom{n}{2} = \frac{n(n-1)}{2}$.
# Mỗi cạnh xuất hiện độc lập với xác suất $p = \frac{1}{3}$.
# Số cạnh kỳ vọng $E[X] = \text{số cạnh tối đa} \times p = \frac{n(n-1)}{2} \times \frac{1}{3} = \frac{n(n-1)}{6}$.
# Vậy đáp án đúng là B.
#
# [ÉP CHỐT LIKELIHOOD]: B (A: 0.1%, B: 99.6%, C: 0.0%, D: 0.0%, E: 0.0%, F: 0.0%, G: 0.1%, H: 0.1%, I: 0.0%, J: 0.0%)
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0262
# MODE  : REASONING
# RAW   :
# Công thức liên hệ: Tỷ lệ tăng trưởng GDP danh nghĩa ≈ Tỷ lệ tăng trưởng GDP thực tế + Tỷ lệ lạm phát.
# Thay số: 6% ≈ 3% + Tỷ lệ lạm phát.
# Tính toán: Tỷ lệ lạm phát ≈ 6% - 3% = 3%.
# Vậy đáp án đúng là B.
# </think>
#
# Suy luận:
# Công thức liên hệ: Tỷ lệ tăng trưởng GDP danh nghĩa ≈ Tỷ lệ tăng trưởng GDP thực tế + Tỷ lệ lạm phát.
# Thay số: 6% ≈ 3% + Tỷ lệ lạm phát.
# Tính toán: Tỷ lệ lạm phát ≈ 6% - 3% = 3%.
# Vậy đáp án đúng là B.
#
# [ÉP CHỐT LIKELIHOOD]: B (A: 0.0%, B: 100.0%, C: 0.0%, D: 0.0%)
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0263
# MODE  : REASONING
# RAW   :
# Điện trở tương đương của hai điện trở mắc song song được tính theo công thức: $R_{eq} = \frac{R_1 \cdot R_2}{R_1 + R_2}$.
# So sánh với các lựa chọn, đáp án C khớp với công thức này.
# Vậy đáp án đúng là C.
# </think>
#
# Suy luận:
# Điện trở tương đương của hai điện trở mắc song song được tính theo công thức: $R_{eq} = \frac{R_1 \cdot R_2}{R_1 + R_2}$.
# So sánh với các lựa chọn, đáp án C khớp với công thức này.
# Vậy đáp án đúng là C.
#
# [ÉP CHỐT LIKELIHOOD]: C (A: 0.0%, B: 0.0%, C: 99.7%, D: 0.1%, E: 0.0%, F: 0.0%, G: 0.1%, H: 0.1%, I: 0.0%, J: 0.0%)
# PRED  : C
# ----------------------------------------------------------------------------------------------------
# QID   : test_0264
# MODE  : REASONING
# RAW   :
# 1. Tính vận tốc $v(t) = y'(t) = 4t^3 - 24t^2 + 36t$.
# 2. Tính gia tốc $a(t) = v'(t) = 12t^2 - 48t + 36$.
# 3. Tìm cực tiểu của $a(t)$ trên $[0, 5]$ bằng cách giải $a'(t) = 24t - 48 = 0 \Rightarrow t = 2$.
# 4. So sánh giá trị $a(2) = 12(4) - 48(2) + 36 = 48 - 96 + 36 = -12$ với các điểm biên $a(0)=36, a(5)=300$.
# 5. Gia tốc nhỏ nhất đạt tại $t=2$.
#
# Vậy đáp án đúng là C.
# </think>
#
# Suy luận:
# Gia tốc $a(t) = y''(t) = 12t^2 - 48t + 36$.
# Tìm cực tiểu của $a(t)$ trên $[0, 5]$ bằng cách giải $a'(t) = 24t - 48 = 0 \Rightarrow t = 2$.
# So sánh giá trị tại $t=2$ ($a(2)=-12
#
# [ÉP CHỐT LIKELIHOOD]: C (A: 0.0%, B: 0.1%, C: 99.5%, D: 0.0%, E: 0.0%, F: 0.0%, G: 0.1%, H: 0.2%, I: 0.0%, J: 0.0%)
# PRED  : C
# ----------------------------------------------------------------------------------------------------
# QID   : test_0265
# MODE  : REASONING
# RAW   :
# Biến đổi Laplace của $t^n$ là $\frac{n!}{s^{n+1}}$.
# Áp dụng cho từng số hạng:
# - $L\{4t^2\} = 4 \cdot \frac{2!}{s^{2+1}} = \frac{8}{s^3}$.
# - $L\{3t\} = 3 \cdot \frac{1!}{s^{1+1}} = \frac{3}{s^2}$.
# - $L\{2\} = 2 \cdot \frac{0!}{s^{0+1}} = \frac{2}{s}$.
# Tổng hợp lại: $\frac{8}{s^3} + \frac{3}{s^2} + \frac{2}{s}$.
# So sánh với các lựa chọn, đáp án A khớp.
#
# Vậy đáp án đúng là A.
# </think>
#
# Suy luận:
# Biến đổi Laplace của $t^n$ là $\frac{n!}{s^{n+1}}$.
# Áp dụng cho từng số hạng:
# - $L\{4t^2\} = 4 \cdot \frac{2!}{s^3} = \frac{8}{s^3}$.
# - $L\{3t\} = 3 \cdot \frac{1!}{s^
#
# [ÉP CHỐT LIKELIHOOD]: A (A: 93.9%, B: 3.4%, C: 0.1%, D: 0.2%, E: 0.3%, F: 0.3%, G: 0.6%, H: 1.1%, I: 0.1%, J: 0.1%)
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0266
# MODE  : REASONING
# RAW   :
# Phương pháp thuỷ luyện là dùng kim loại hoạt động mạnh hơn (như Zn, Fe, Al...) để đẩy kim loại kém hoạt động hơn ra khỏi dung dịch muối.
# Xét các phương án:
# A. Zn + CuSO₄ → Cu + ZnSO₄: Zn hoạt động mạnh hơn Cu, Zn đẩy Cu ra khỏi dung dịch muối. Đây là phương pháp thuỷ luyện.
# B. H₂ + CuO → Cu + H₂O: Dùng khí H₂ khử CuO. Đây là phương pháp nhiệt luyện.
# C. CuCl₂ → Cu + Cl₂: Phân hủy nhiệt. Đây là phương pháp điện phân hoặc nhiệt phân (không phải thuỷ luyện).
# D. 2CuSO₄ + 2H₂O → 2Cu + 2H₂SO₄ + O₂: Điện phân dung dịch CuSO₄. Đây là phương pháp điện phân.
#
# Vậy đáp án đúng là A.
# </think>
#
# Phương pháp thuỷ luyện là dùng kim loại hoạt động mạnh hơn để đẩy kim loại kém hoạt động hơn ra khỏi dung dịch muối.
# Xét các phương án:
# A. Zn hoạt động mạnh hơn Cu, Zn đẩy Cu ra khỏi dung dịch CuSO₄. Đây là phương pháp thuỷ luyện.
# B. Dùng H₂ khử CuO. Đây là phương pháp nhiệt luyện.
# C. Phân hủy nhiệt. Đây là phương pháp điện phân hoặc nhiệt phân.
# D. Điện
#
# [ÉP CHỐT LIKELIHOOD]: A (A: 99.5%, B: 0.0%, C: 0.2%, D: 0.4%)
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0267
# MODE  : REASONING
# RAW   :
# Áp suất khí quyển ở mực nước biển (sea level) là 101.3 kPa. Áp suất riêng phần của oxy trong không khí là 21% (0.21). Áp suất riêng phần của oxy trong phế nang (PAO2) thấp hơn do pha loãng bởi hơi nước (áp suất hơi nước 47 mmHg ≈ 6.3 kPa) và CO2.
# Công thức tính: PAO2 = (FiO2 * (Patm - PH2O)) - (PaCO2 / R).
# Thay số: (0.21 * (101.3 - 6.3)) - (40 / 0.8) ≈ (0.21 * 95) - 50 ≈ 20 - 50 ≈ 30 mmHg (sai, cần tính lại đơn vị).
# Tính theo mmHg: PAO2 ≈ 150 mmHg.
# Chuyển đổi sang kPa: 150 mmHg / 7.5 ≈ 20 kPa.
# Tuy nhiên, các lựa chọn có giá trị thấp hơn. Kiểm tra lại: Áp suất riêng phần oxy trong phế nang thường khoảng 104 mmHg (13.9 kPa).
# Tính chính xác: (0.21 * (760 - 47)) - (40/0
#
# [ÉP CHỐT LIKELIHOOD]: E (A: 0.0%, B: 10.7%, C: 0.2%, D: 0.5%, E: 85.1%, F: 0.8%, G: 0.7%, H: 1.2%, I: 0.5%, J: 0.3%)
# PRED  : E
# ----------------------------------------------------------------------------------------------------
# QID   : test_0268
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B.
#
# Giải thích:
# Tư tưởng Hồ Chí Minh là hệ' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0269
# MODE  : REASONING
# RAW   :
# 1. Tính hệ số chọn lọc $k$ từ phương trình đã cho với $ee_{\text{catalyst}} = 80$.
# 2. Thay số vào: $k = \frac{1 + \frac{80}{100}}{1 - \frac{80}{100}} = \frac{1 + 0.8}{1 - 0.8} = \frac{1.8}{0.2}$.
# 3. Tính toán: $1.8 / 0.2 = 9$.
# 4. Đề bài hỏi tỉ lệ tốc độ của Con đường A so với Con đường B, chính là hệ số chọn lọc $k$.
# 5. Kết quả là 9.
#
# Đáp án: I.
# </think>
#
# Suy luận:
# Hệ số chọn lọc $k$ được tính bằng công thức $k = \frac{1 + \frac{ee_{\text{catalyst}}}{100}}{1 - \frac{ee_{\text{catalyst}}}{100}}$.
# Thay $ee_{\text{catalyst}} = 80$ vào: $k = \frac{1 + 0.8}{1 - 0.8} = \frac{1.8}{0.2} = 9$.
# Tỉ lệ tốc độ Con đường A so với Con đường B
#
# [ÉP CHỐT LIKELIHOOD]: I (A: 0.0%, B: 0.0%, C: 0.0%, D: 0.0%, E: 0.0%, F: 0.0%, G: 0.0%, H: 0.1%, I: 99.7%, J: 0.1%)
# PRED  : I
# ----------------------------------------------------------------------------------------------------
# QID   : test_0270
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'D. Các khiếu nại về sa thải sai trái cung cấp các ngoại lệ' -> Selected: D
# PRED  : D
# ----------------------------------------------------------------------------------------------------
# QID   : test_0271
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A.
#
# Giải thích:
# - Máu di chuyển một chiều trong' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0272
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A. Héctor
#
# Giải thích:
# Theo đoạn văn "Mig' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0273
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'D.
#
# Giải thích:
# - Hệ thống cơ quan nhà nước Việt' -> Selected: D
# PRED  : D
# ----------------------------------------------------------------------------------------------------
# QID   : test_0274
# MODE  : REASONING
# RAW   :
# Quốc hội khóa I được thành lập tại Hà Nội vào ngày 2 tháng 3 năm 1946.
# Vậy đáp án đúng là A.
# </think>
#
# Suy luận:
# Quốc hội khóa I được thành lập tại Hà Nội vào ngày 2 tháng 3 năm 1946.
# Vậy đáp án đúng là A.
#
# [ÉP CHỐT LIKELIHOOD]: A (A: 99.9%, B: 0.1%, C: 0.0%, D: 0.0%)
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0275
# MODE  : REASONING
# RAW   :
# Chu kỳ dao động của con lắc đơn trong trường hấp dẫn được tính bằng công thức $T = 2\pi \sqrt{\frac{L}{g}}$.
# So sánh với các lựa chọn, đáp án A khớp chính xác với công thức này.
# Vậy đáp án đúng là A.
# </think>
#
# Suy luận:
# Công thức chu kỳ dao động của con lắc đơn là $T = 2\pi \sqrt{\frac{L}{g}}$.
# So sánh với các lựa chọn, đáp án A khớp chính xác.
# Vậy đáp án đúng là A.
#
# [ÉP CHỐT LIKELIHOOD]: A (A: 99.4%, B: 0.0%, C: 0.0%, D: 0.0%, E: 0.1%, F: 0.0%, G: 0.2%, H: 0.2%, I: 0.0%, J: 0.0%)
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0276
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B. GDP đo lường tổng sản phẩm quốc nội, phản ánh quy mô' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0277
# MODE  : REASONING
# RAW   :
# Tổng của hai biến ngẫu nhiên độc lập tuân theo phân phối Poisson có tham số là tổng các tham số của chúng.
# Công thức: Nếu $X \sim \text{Poisson}(\lambda_1)$ và $Y \sim \text{Poisson}(\lambda_2)$ độc lập, thì $X+Y \sim \text{Poisson}(\lambda_1 + \lambda_2)$.
# Vậy đáp án đúng là A.
# </think>
#
# Suy luận:
# Tổng của hai biến ngẫu nhiên độc lập tuân theo phân phối Poisson có tham số là tổng các tham số của chúng.
# Công thức: Nếu $X \sim \text{Poisson}(\lambda_1)$ và $Y \sim \text{Poisson}(\lambda_2)$ độc lập, thì $X+Y \sim \text{Poisson}(\lambda_1 + \lambda_2)$.
# Vậy đáp án đúng là A.
#
# [ÉP CHỐT LIKELIHOOD]: A (A: 98.6%, B: 0.2%, C: 0.1%, D: 0.1%, E: 0.2%, F: 0.1%, G: 0.3%, H: 0.4%, I: 0.0%, J: 0.1%)
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0278
# MODE  : REASONING
# RAW   :
# Tổng trở chỉ có tính chất điện trở khi mạch đạt cộng hưởng điện, tức là cảm kháng bằng dung kháng: $\omega_0 L = \frac{1}{\omega_0 C}$.
# Công thức tính tần số cộng hưởng: $\omega_0 = \frac{1}{\sqrt{LC}}$.
# Thay số: $L = 0.2$ H, $C = 5 \mu F = 5 \times 10^{-6}$ F.
# $\omega_0 = \frac{1}{\sqrt{0.2 \times 5 \times 10^{-6}}} = \frac{1}{\sqrt{1 \times 10^{-6}}} = \frac{1}{10^{-3}} = 1000$ rad/s.
# Vậy đáp án đúng là E.
# </think>
#
# Suy luận:
# Tổng trở chỉ có tính chất điện trở khi mạch đạt cộng hưởng điện, tức là $\omega_0 = \frac{1}{\sqrt{LC}}$.
# Thay số: $L = 0.2$ H, $C = 5 \times 10^{-6}$ F.
# $\omega_0 = \frac{1}{\sqrt{0.2 \times 5 \times 10^{-6}}} = \frac{1}{\sqrt{10^{-6}}} = 1000$ rad
#
# [ÉP CHỐT LIKELIHOOD]: E (A: 0.0%, B: 0.0%, C: 0.0%, D: 0.0%, E: 100.0%, F: 0.0%, G: 0.0%, H: 0.0%, I: 0.0%, J: 0.0%)
# PRED  : E
# ----------------------------------------------------------------------------------------------------
# QID   : test_0279
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B.
#
# Giải thích:
# - Đoạn văn nói rõ: "Có' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0280
# MODE  : REASONING
# RAW   :
# Năng lượng trung bình $\langle E \rangle = \frac{\sum E_i e^{-E_i/kT}}{\sum e^{-E_i/kT}}$.
# Thay $E_1=0, E_2=E$: Tử số là $0 \cdot e^0 + E \cdot e^{-E/kT} = E e^{-E/kT}$. Mẫu số là $e^0 + e^{-E/kT} = 1 + e^{-E/kT}$.
# Kết quả là $\frac{E e^{-E/kT}}{1 + e^{-E/kT}}$.
# Vậy đáp án đúng là B.
# </think>
#
# Suy luận:
# Năng lượng trung bình $\langle E \rangle = \frac{\sum E_i e^{-E_i/kT}}{\sum e^{-E_i/kT}}$.
# Thay $E_1=0, E_2=E$: Tử số là $0 \cdot 1 + E \cdot e^{-E/kT} = E e^{-E/kT}$. Mẫu số là $1 + e^{-E/kT}$.
# Vậy đáp án đúng là B.
#
# [ÉP CHỐT LIKELIHOOD]: B (A: 0.0%, B: 99.7%, C: 0.0%, D: 0.0%, E: 0.0%, F: 0.0%, G: 0.1%, H: 0.2%, I: 0.0%, J: 0.0%)
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0281
# MODE  : REASONING
# RAW   :
# Biến áp lý tưởng có tỉ số vòng dây bằng tỉ số điện áp và tỉ số dòng điện nghịch đảo: $N_1/N_2 = I_2/I_1$.
# Thay số: $1000/250 = 10/1 \Rightarrow I_1 = I_2 / 10 = 10 / 10 = 1$ A.
# Tuy nhiên, đề bài hỏi dòng điện sơ cấp, nhưng các đáp án đều lớn hơn 1A (tối thiểu 2.5A).
# Kiểm tra lại công thức: $V_1/V_2 = N_1/N_2 = I_2/I_1$.
# $V_1 = 240V$, $N_1 = 1000$, $N_2 = 250$.
# Tỉ số biến áp $k = 1000/250 = 4$.
# $V_2 = V_1 / 4 = 60V$.
# Công suất đầu vào = Công suất đầu ra (biến áp lý tưởng): $P_1 = P_2 \Rightarrow V_1 * I_1 = V_2 * I_2$.
# $240 * I_1 = 60 * 10 \Rightarrow 240 * I_1 = 600 \Rightarrow I_
#
# [ÉP CHỐT LIKELIHOOD]: E (A: 0.2%, B: 1.1%, C: 1.0%, D: 3.1%, E: 31.8%, F: 16.0%, G: 3.9%, H: 5.6%, I: 8.9%, J: 28.4%)
# PRED  : E
# ----------------------------------------------------------------------------------------------------
# QID   : test_0282
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A. Mạc Đĩnh Chi
#
# Giải thích:
# Theo đoạn văn "' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0283
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A. Tôi không thể chia sẻ nội dung liên quan đến vấn đề này' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0284
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'C. chr()
#
# Giải thích:
# - `enumerate()`: Chấp' -> Selected: C
# PRED  : C
# ----------------------------------------------------------------------------------------------------
# QID   : test_0285
# MODE  : REASONING
# RAW   :
# Gia tốc trọng trường tại khoảng cách $r$ từ tâm hành tinh hình cầu có mật độ đều được tính bằng công thức $g' = \frac{G M(r)}{r^2}$, trong đó $M(r)$ là khối lượng của phần hành tinh bán kính $r$.
# Khối lượng $M(r)$ tỉ lệ với thể tích $V(r) = \frac{4}{3}\pi r^3$, nên $M(r) = M \cdot \frac{r^3}{R^3}$.
# Thay vào công thức: $g' = \frac{G (M \cdot r^3/R^3)}{r^2} = \frac{GM}{R^3} r$.
# Tại bề mặt ($r=R$): $g = \frac{GM}{R^2} \Rightarrow \frac{GM}{R^3} = \frac{g}{R}$.
# Tại $r = R/2$: $g' = \frac{g}{R} \cdot \frac{R}{2} = \frac{g}{2}$.
# Vậy đáp án đúng là B.
# </think>
#
# Suy luận:
# Gia tốc trọng trường bên trong hành tinh hình cầu tỉ lệ với bán kính: $g' = \frac{GM(r)}{r^2} = \frac{G(M \cdot r^3/R^3)}{r^2}
#
# [ÉP CHỐT LIKELIHOOD]: B (A: 0.0%, B: 96.9%, C: 0.0%, D: 0.1%, E: 0.1%, F: 0.0%, G: 2.4%, H: 0.3%, I: 0.0%, J: 0.0%)
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0286
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'C.
#
# Giải thích:
# Theo đoạn văn: "Năm 1' -> Selected: C
# PRED  : C
# ----------------------------------------------------------------------------------------------------
# QID   : test_0287
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'D.
#
# Giải thích:
# - Bán tài liệu mật (A)' -> Selected: D
# PRED  : D
# ----------------------------------------------------------------------------------------------------
# QID   : test_0288
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B. Tại mức chiết khấu.
#
# Giải thích:
# - Mệnh giá' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0289
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'C.
#
# Giải thích: Khi mức lương tối thiểu được đặt cao' -> Selected: C
# PRED  : C
# ----------------------------------------------------------------------------------------------------
# QID   : test_0290
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A. Lợi ích kinh tế.
#
# Giải thích: Theo quan điểm của' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0291
# MODE  : REASONING
# RAW   :
# Trạng thái cân bằng nghĩa là gia tốc và vận tốc bằng 0, tức là $\frac{d^2 x}{dt^2} = 0$ và $\frac{dx}{dt} = 0$.
# Thay vào phương trình vi phân: $m(0) + b(0) + kx = mg \Rightarrow kx = mg \Rightarrow x = \frac{mg}{k}$.
# Vậy đáp án đúng là B.
# </think>
#
# Suy luận:
# Trạng thái cân bằng nghĩa là gia tốc và vận tốc bằng 0, tức là $\frac{d^2 x}{dt^2} = 0$ và $\frac{dx}{dt} = 0$.
# Thay vào phương trình vi phân: $m(0) + b(0) + kx = mg \Rightarrow kx = mg \Rightarrow x = \frac{mg}{k}$.
# Vậy đáp án đúng là B.
#
# [ÉP CHỐT LIKELIHOOD]: B (A: 0.1%, B: 99.2%, C: 0.0%, D: 0.0%, E: 0.1%, F: 0.0%, G: 0.1%, H: 0.4%, I: 0.0%, J: 0.0%)
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0292
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B. Kiểm tra lại hồ sơ để đảm bảo đã nộp đầy đủ và' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0293
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'D. Ở các nước châu Á, phương Đông.
#
# Giải thích:' -> Selected: D
# PRED  : D
# ----------------------------------------------------------------------------------------------------
# QID   : test_0294
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'D. Phá hoại hoặc làm trì hoãn các dự án đầu tư quan' -> Selected: D
# PRED  : D
# ----------------------------------------------------------------------------------------------------
# QID   : test_0295
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A. Olivier Messiaen.
#
# Giải thích:
# Trong đoạn văn' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0296
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B. Khỉ vàng.
#
# Giải thích:
# - Đoạn văn nói' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0297
# MODE  : REASONING
# RAW   :
# Biến đổi biểu thức $\tan \theta + \cot \theta = \frac{\sin \theta}{\cos \theta} + \frac{\cos \theta}{\sin \theta} = \frac{\sin^2 \theta + \cos^2 \theta}{\sin \theta \cos \theta} = \frac{1}{\sin \theta \cos \theta}$.
# Thay vào phương trình đã cho: $\frac{1}{\sin \theta \cos \theta} = 3 \Rightarrow \sin \theta \cos \theta = \frac{1}{3}$.
# Ta cần tìm $\sin 2\theta = 2 \sin \theta \cos \theta = 2 \cdot \frac{1}{3} = \frac{2}{3}$.
# Vậy đáp án đúng là D.
# </think>
#
# Suy luận:
# Biến đổi $\tan \theta + \cot \theta = \frac{1}{\sin \theta \cos \theta} = 3 \Rightarrow \sin \theta \cos \theta = \frac{1}{3}$.
# Suy ra $\sin 2\theta = 2 \sin \theta \cos \theta = 2 \cdot \frac{1}{3} = \frac{2}{3}$.
# Vậy đáp án đúng là D.
#
# [ÉP CHỐT LIKELIHOOD]: D (A: 0.0%, B: 0.0%, C: 0.0%, D: 100.0%, E: 0.0%, F: 0.0%, G: 0.0%, H: 0.0%, I: 0.0%, J: 0.0%)
# PRED  : D
# ----------------------------------------------------------------------------------------------------
# QID   : test_0298
# MODE  : REASONING
# RAW   :
# Tần số cơ bản của dây đàn hồi là $f_1 = \frac{1}{2L} \sqrt{\frac{T}{\mu}}$.
# Khi lực căng tăng gấp 4 lần ($T' = 4T$), các đại lượng $L$ và $\mu$ không đổi.
# Thay vào công thức: $f_1' = \frac{1}{2L} \sqrt{\frac{4T}{\mu}} = 2 \left( \frac{1}{2L} \sqrt{\frac{T}{\mu}} \right) = 2f_1$.
# Vậy tần số cơ bản tăng gấp đôi.
#
# Đáp án: B.
# </think>
#
# Suy luận:
# Tần số cơ bản của dây đàn hồi là $f_1 = \frac{1}{2L} \sqrt{\frac{T}{\mu}}$.
# Khi lực căng tăng gấp 4 lần ($T' = 4T$), các đại lượng $L$ và $\mu$ không đổi.
# Thay vào công thức: $f_1' = \frac{1}{2L} \sqrt{\frac{4T}{\mu}} = 2 \left( \frac{1}{2L} \sqrt{\frac{T}{\mu}} \right) = 2f_1$.
# Vậy tần số cơ bản tăng gấp đôi.
#
# Đáp án: B.
#
# [ÉP CHỐT LIKELIHOOD]: B (A: 0.0%, B: 99.6%, C: 0.0%, D: 0.0%, E: 0.0%, F: 0.0%, G: 0.1%, H: 0.2%, I: 0.0%, J: 0.0%)
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0299
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B.
#
# Giải thích:
# - "Thị trường Tài chính:' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0300
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A. Chứa nhóm chức năng sulfonyl (lưu huỳnh' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0301
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B. Đắk Lắk.
#
# Giải thích:
# - Tỉnh Đắk Lắk đã' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0302
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A.
#
# Giải thích:
# Theo đoạn văn "Năm 20' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0303
# MODE  : REASONING
# RAW   :
# Công thức tính lãi kép hàng năm: $A = P(1 + r)^n$.
# Thay số: $P = 80.000$, $r = 0.06$, $n = 2$.
# Tính toán: $A = 80.000 * (1 + 0.06)^2 = 80.000 * 1.1236 = 89.888$.
# So sánh với các đáp án, không khớp chính xác.
# Kiểm tra lại: Có thể đề bài hỏi lãi đơn?
# Lãi đơn: $A = P(1 + n*r) = 80.000 * (1 + 2*0.06) = 80.000 * 1.12 = 89.600$.
# Đáp án A khớp với lãi đơn.
# Vậy chọn A.
# </think>
#
# Suy luận:
# Nếu tính lãi đơn: $A = P(1 + n \times r) = 80.000 \times (1 + 2 \times 0.06) = 80.000 \times 1.12 = 89.600$.
# Nếu tính lãi kép: $A = P(1 + r)^n = 80.000 \times (1
#
# [ÉP CHỐT LIKELIHOOD]: A (A: 97.4%, B: 1.7%, C: 0.4%, D: 0.5%)
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0304
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B.
#
# Giải thích:
# Nguyên lý về sự lựa chọn hợp lý' -> Selected: B
# PRED  : B
# ...
# Vậy đáp án đúng là A.
# </think>
#
# Suy luận:
# Thể tích hình hộp song diện bằng giá trị tuyệt đối của định thức ma trận có các cột là các vector: $V = |\det(\mathbf{a}, \mathbf{b}, \mathbf{c})|$.
# Tính định thức: $\det \begin{pm
#
# [ÉP CHỐT LIKELIHOOD]: A (A: 88.2%, B: 0.2%, C: 0.1%, D: 0.2%, E: 1.0%, F: 0.8%, G: 0.9%, H: 8.1%, I: 0.3%, J: 0.2%)
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0451
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A. Khổng tử đề cao Nhân, Nghĩa, Lễ. Chính' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0452
# MODE  : REASONING
# RAW   :
# Ma trận $A$ được cho là $\begin{pmatrix} 1 & 0 & 0 \\ 2 & 1 & 0 \\ 0 & 2 & 1 \end{pmatrix}$ (dựa trên các số 1, 2, 0, 2, 1 trong đề bài, mặc dù có lỗi đánh máy trong đề gốc, nhưng cấu trúc tam giác dưới với đường chéo là 1, 1, 1 là hợp lý nhất để khớp với các lựa chọn). Tuy nhiên, nhìn kỹ đề bài: "$= \begin{pmatrix}& 1 & 0 \\& 2 & 1 \\& 0 & 2."$. Có vẻ thiếu số cuối cùng và dấu ngoặc. Giả sử ma trận là tam giác dưới với đường chéo là 1, 1, 1. Khi đó giá trị riêng bằng các phần tử trên đường chéo chính.
# Nếu ma trận là $\begin{pmatrix} 1 & 0 & 0 \\ 2 & 1 & 0 \\ 0 & 2 & 1 \end{pmatrix}$, các giá trị riêng là 1, 1, 1. Không có đáp án nào khớp.
# Xem lại đề bài: Có thể ma trận là $\begin{pmatrix} 1 & 0 & 0 \\ 2 & 2 & 0 \\ 0 & 2 & 2
#
# [ÉP CHỐT LIKELIHOOD]: G (A: 0.0%, B: 2.3%, C: 0.5%, D: 0.5%, E: 7.9%, F: 24.6%, G: 57.1%, H: 1.7%, I: 0.4%, J: 5.1%)
# PRED  : G
# ----------------------------------------------------------------------------------------------------
# QID   : test_0453
# MODE  : REASONING
# RAW   :
# Biến đổi Laplace của $e^{-at} \cos(bt)$ được tính theo tính chất dịch chuyển tần số (s-shifting): $\mathcal{L}\{e^{-at} g(t)\} = G(s+a)$, với $G(s) = \mathcal{L}\{\cos(bt)\} = \frac{s}{s^2 + b^2}$.
# Thay $s$ bằng $s+a$ vào biểu thức của $G(s)$: $\frac{s+a}{(s+a)^2 + b^2}$.
# Vậy đáp án đúng là A.
# </think>
#
# Suy luận:
# Biến đổi Laplace của $\cos(bt)$ là $\frac{s}{s^2 + b^2}$.
# Áp dụng tính chất dịch chuyển tần số: $\mathcal{L}\{e^{-at} \cos(bt)\} = \frac{s+a}{(s+a)^2 + b^2}$.
# Vậy đáp án đúng là A.
#
# [ÉP CHỐT LIKELIHOOD]: A (A: 99.2%, B: 0.1%, C: 0.0%, D: 0.1%, E: 0.2%, F: 0.1%, G: 0.3%, H: 0.1%, I: 0.0%, J: 0.0%)
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0454
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'D.
#
# Giải thích:
# - Hành động phù hợp nhất với khái' -> Selected: D
# PRED  : D
# ----------------------------------------------------------------------------------------------------
# QID   : test_0455
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B.
#
# Giải thích:
# - Doanh nghiệp tư nhân là loại hình' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0456
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'C.
#
# Giải thích:
# - Máy khế tích tai trong (' -> Selected: C
# PRED  : C
# ----------------------------------------------------------------------------------------------------
# QID   : test_0457
# MODE  : REASONING
# RAW   :
# 1. Hàm lợi nhuận của mỗi hãng: $\pi = TR - TC = P \cdot q - C(q) = (20 - Q)q - 2q = (20 - q_X - q_Y)q - 2q$.
# 2. Điều kiện tối ưu hóa (điều kiện FOC): $\frac{\partial \pi}{\partial q_X} = 20 - 2q_X - q_Y - 2 = 0 \Rightarrow 18 - 2q_X - q_Y = 0 \Rightarrow q_X = 9 - 0.5q_Y$.
# 3. Do tính đối xứng, $q_X = q_Y = q$. Thay vào phương trình: $q = 9 - 0.5q \Rightarrow 1.5q = 9 \Rightarrow q = 6$.
# Vậy đáp án đúng là D.
# </think>
#
# Suy luận:
# Lợi nhuận của mỗi hãng: $\pi = (20 - q_X - q_Y)q_X - 2q_X$.
# Điều kiện tối ưu: $\frac{\partial \pi}{\partial q_X} = 20 - 2q_X - q_Y - 2 = 0 \Rightarrow 18 - 2q_X - q_Y = 0$.
# Do tính đối xứng, $q_X = q_Y = q \Rightarrow 18 - 3q =
#
# [ÉP CHỐT LIKELIHOOD]: D (A: 0.0%, B: 0.2%, C: 0.0%, D: 98.7%, E: 0.0%, F: 0.9%, G: 0.1%, H: 0.0%, I: 0.0%, J: 0.0%)
# PRED  : D
# ----------------------------------------------------------------------------------------------------
# QID   : test_0458
# MODE  : REASONING
# RAW   :
# Tính giá trị riêng của ma trận $A$ bằng cách giải phương trình đặc trưng $\det(A - \lambda I) = 0$.
# $\det \begin{pmatrix} -1-\lambda & 3 \\ -3 & -1-\lambda \end{pmatrix} = (-1-\lambda)^2 - (3)(-3) = \lambda^2 + 2\lambda + 1 + 9 = \lambda^2 + 2\lambda + 10 = 0$.
# Giải phương trình bậc hai: $\lambda = \frac{-2 \pm \sqrt{4 - 40}}{2} = -1 \pm i3$.
# Các giá trị riêng là số phức liên hợp có phần thực âm ($Re(\lambda) = -1 < 0$).
# Hệ thống tuyến tính ổn định tiệm cận khi tất cả phần thực của giá trị riêng đều âm.
# Vậy đáp án đúng là D.
# </think>
#
# Suy luận:
# Tính giá trị riêng của ma trận $A$ qua phương trình đặc trưng $\det(A - \lambda I) = 0$.
# Ta có $\lambda^2 + 2\lambda + 10 = 0 \Rightarrow \lambda = -1 \pm 3i$.
# Các giá trị riêng là số phức liên hợp với phần thực âm ($Re(\lambda) = -1 < 0$).
# Hệ thống ổn định tiệm cận
#
# [ÉP CHỐT LIKELIHOOD]: D (A: 0.0%, B: 0.0%, C: 0.0%, D: 100.0%, E: 0.0%, F: 0.0%, G: 0.0%, H: 0.0%, I: 0.0%, J: 0.0%)
# PRED  : D
# ----------------------------------------------------------------------------------------------------
# QID   : test_0459
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'C. APT-X100
#
# Giải thích:
# - Trong' -> Selected: C
# PRED  : C
# ----------------------------------------------------------------------------------------------------
# QID   : test_0460
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'A. Lợn biển (Manatee) và cá heo sông Amazon.' -> Selected: A
# PRED  : A
# ----------------------------------------------------------------------------------------------------
# QID   : test_0461
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B.
# </think>
#
# B' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0462
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'B. Người khôn dồn ra mặt.
#
# Giải thích:
# Câu tục' -> Selected: B
# PRED  : B
# ----------------------------------------------------------------------------------------------------
# QID   : test_0463
# MODE  : KNOWLEDGE
# RAW   :
# Generated: 'D. Phương pháp giáo dục thuyết phục dựa vào tác phong và nghệ' -> Selected: D
# PRED  : D
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# EVALUATION (LIKELIHOOD METHOD)
# ====================================================================================================
# test_0201    | Pred=B  | GT=A  | ✗
# test_0202    | Pred=D  | GT=D  | ✓
# test_0203    | Pred=B  | GT=B  | ✓
# test_0204    | Pred=A  | GT=A  | ✓
# test_0205    | Pred=B  | GT=B  | ✓
# test_0206    | Pred=D  | GT=D  | ✓
# test_0207    | Pred=B  | GT=B  | ✓
# test_0208    | Pred=B  | GT=B  | ✓
# test_0209    | Pred=A  | GT=D  | ✗
# test_0210    | Pred=B  | GT=B  | ✓
# test_0211    | Pred=A  | GT=A  | ✓
# test_0212    | Pred=A  | GT=A  | ✓
# test_0213    | Pred=D  | GT=D  | ✓
# test_0214    | Pred=B  | GT=B  | ✓
# test_0215    | Pred=A  | GT=A  | ✓
# test_0216    | Pred=B  | GT=B  | ✓
# test_0217    | Pred=B  | GT=B  | ✓
# test_0218    | Pred=A  | GT=A  | ✓
# test_0219    | Pred=B  | GT=B  | ✓
# test_0220    | Pred=J  | GT=J  | ✓
# test_0221    | Pred=A  | GT=A  | ✓
# test_0222    | Pred=G  | GT=C  | ✗
# test_0223    | Pred=H  | GT=C  | ✗
# test_0224    | Pred=B  | GT=B  | ✓
# test_0225    | Pred=C  | GT=C  | ✓
# test_0226    | Pred=A  | GT=A  | ✓
# test_0227    | Pred=D  | GT=A  | ✗
# test_0228    | Pred=G  | GT=J  | ✗
# test_0229    | Pred=C  | GT=D  | ✗
# test_0230    | Pred=C  | GT=B  | ✗
# test_0231    | Pred=B  | GT=B  | ✓
# test_0232    | Pred=A  | GT=A  | ✓
# test_0233    | Pred=A  | GT=A  | ✓
# test_0234    | Pred=A  | GT=A  | ✓
# test_0235    | Pred=B  | GT=B  | ✓
# test_0236    | Pred=A  | GT=A  | ✓
# test_0237    | Pred=A  | GT=A  | ✓
# test_0238    | Pred=B  | GT=B  | ✓
# test_0239    | Pred=B  | GT=B  | ✓
# test_0240    | Pred=D  | GT=B  | ✗
# test_0241    | Pred=D  | GT=D  | ✓
# test_0242    | Pred=C  | GT=D  | ✗
# test_0243    | Pred=B  | GT=B  | ✓
# test_0244    | Pred=A  | GT=A  | ✓
# test_0245    | Pred=E  | GT=E  | ✓
# test_0246    | Pred=F  | GT=E  | ✗
# test_0247    | Pred=C  | GT=D  | ✗
# test_0248    | Pred=B  | GT=B  | ✓
# test_0249    | Pred=B  | GT=B  | ✓
# test_0250    | Pred=D  | GT=D  | ✓
# test_0251    | Pred=H  | GT=H  | ✓
# test_0252    | Pred=C  | GT=C  | ✓
# test_0253    | Pred=D  | GT=D  | ✓
# test_0254    | Pred=A  | GT=B  | ✗
# test_0255    | Pred=H  | GT=C  | ✗
# test_0256    | Pred=B  | GT=C  | ✗
# test_0257    | Pred=A  | GT=C  | ✗
# test_0258    | Pred=A  | GT=B  | ✗
# test_0259    | Pred=A  | GT=A  | ✓
# test_0260    | Pred=B  | GT=B  | ✓
# test_0261    | Pred=B  | GT=B  | ✓
# test_0262    | Pred=B  | GT=B  | ✓
# test_0263    | Pred=C  | GT=C  | ✓
# test_0264    | Pred=C  | GT=C  | ✓
# test_0265    | Pred=A  | GT=A  | ✓
# test_0266    | Pred=A  | GT=A  | ✓
# test_0267    | Pred=E  | GT=B  | ✗
# test_0268    | Pred=B  | GT=B  | ✓
# test_0269    | Pred=I  | GT=I  | ✓
# test_0270    | Pred=D  | GT=D  | ✓
# test_0271    | Pred=A  | GT=D  | ✗
# test_0272    | Pred=A  | GT=A  | ✓
# test_0273    | Pred=D  | GT=D  | ✓
# test_0274    | Pred=A  | GT=A  | ✓
# test_0275    | Pred=A  | GT=A  | ✓
# test_0276    | Pred=B  | GT=B  | ✓
# test_0277    | Pred=A  | GT=A  | ✓
# test_0278    | Pred=E  | GT=E  | ✓
# test_0279    | Pred=B  | GT=B  | ✓
# test_0280    | Pred=B  | GT=B  | ✓
# test_0281    | Pred=E  | GT=A  | ✗
# test_0282    | Pred=A  | GT=A  | ✓
# test_0283    | Pred=A  | GT=A  | ✓
# test_0284    | Pred=C  | GT=C  | ✓
# test_0285    | Pred=B  | GT=B  | ✓
# test_0286    | Pred=C  | GT=C  | ✓
# test_0287    | Pred=D  | GT=D  | ✓
# test_0288    | Pred=B  | GT=B  | ✓
# test_0289    | Pred=C  | GT=C  | ✓
# test_0290    | Pred=A  | GT=A  | ✓
# test_0291    | Pred=B  | GT=B  | ✓
# test_0292    | Pred=B  | GT=B  | ✓
# test_0293    | Pred=D  | GT=D  | ✓
# test_0294    | Pred=D  | GT=C  | ✗
# test_0295    | Pred=A  | GT=A  | ✓
# test_0296    | Pred=B  | GT=B  | ✓
# test_0297    | Pred=D  | GT=D  | ✓
# test_0298    | Pred=B  | GT=B  | ✓
# test_0299    | Pred=B  | GT=B  | ✓
# test_0300    | Pred=A  | GT=A  | ✓
# test_0301    | Pred=B  | GT=A  | ✗
# test_0302    | Pred=A  | GT=A  | ✓
# test_0303    | Pred=A  | GT=A  | ✓
# test_0304    | Pred=B  | GT=B  | ✓
# test_0305    | Pred=C  | GT=C  | ✓
# test_0306    | Pred=A  | GT=A  | ✓
# test_0307    | Pred=H  | GT=H  | ✓
# test_0308    | Pred=A  | GT=B  | ✗
# test_0309    | Pred=A  | GT=B  | ✗
# test_0310    | Pred=E  | GT=E  | ✓
# test_0311    | Pred=A  | GT=A  | ✓
# test_0312    | Pred=A  | GT=A  | ✓
# test_0313    | Pred=A  | GT=A  | ✓
# test_0314    | Pred=A  | GT=A  | ✓
# test_0315    | Pred=A  | GT=A  | ✓
# test_0316    | Pred=D  | GT=D  | ✓
# test_0317    | Pred=C  | GT=C  | ✓
# test_0318    | Pred=C  | GT=C  | ✓
# test_0319    | Pred=A  | GT=A  | ✓
# test_0320    | Pred=D  | GT=D  | ✓
# test_0321    | Pred=C  | GT=C  | ✓
# test_0322    | Pred=B  | GT=B  | ✓
# test_0323    | Pred=A  | GT=A  | ✓
# test_0324    | Pred=C  | GT=C  | ✓
# test_0325    | Pred=A  | GT=A  | ✓
# test_0326    | Pred=E  | GT=E  | ✓
# test_0327    | Pred=B  | GT=B  | ✓
# test_0328    | Pred=D  | GT=D  | ✓
# test_0329    | Pred=B  | GT=A  | ✗
# test_0330    | Pred=D  | GT=D  | ✓
# test_0331    | Pred=A  | GT=C  | ✗
# test_0332    | Pred=A  | GT=A  | ✓
# test_0333    | Pred=B  | GT=B  | ✓
# test_0334    | Pred=A  | GT=A  | ✓
# test_0335    | Pred=A  | GT=A  | ✓
# test_0336    | Pred=D  | GT=B  | ✗
# test_0337    | Pred=B  | GT=B  | ✓
# test_0338    | Pred=D  | GT=C  | ✗
# test_0339    | Pred=A  | GT=A  | ✓
# test_0340    | Pred=C  | GT=C  | ✓
# test_0341    | Pred=D  | GT=D  | ✓
# test_0342    | Pred=B  | GT=B  | ✓
# test_0343    | Pred=B  | GT=B  | ✓
# test_0344    | Pred=C  | GT=C  | ✓
# test_0345    | Pred=A  | GT=A  | ✓
# test_0346    | Pred=A  | GT=B  | ✗
# test_0347    | Pred=A  | GT=B  | ✗
# test_0348    | Pred=H  | GT=H  | ✓
# test_0349    | Pred=C  | GT=C  | ✓
# test_0350    | Pred=C  | GT=C  | ✓
# test_0351    | Pred=G  | GT=G  | ✓
# test_0352    | Pred=B  | GT=B  | ✓
# test_0353    | Pred=B  | GT=B  | ✓
# test_0354    | Pred=B  | GT=B  | ✓
# test_0355    | Pred=A  | GT=A  | ✓
# test_0356    | Pred=C  | GT=C  | ✓
# test_0357    | Pred=C  | GT=C  | ✓
# test_0358    | Pred=A  | GT=A  | ✓
# test_0359    | Pred=B  | GT=B  | ✓
# test_0360    | Pred=A  | GT=D  | ✗
# test_0361    | Pred=A  | GT=A  | ✓
# test_0362    | Pred=A  | GT=A  | ✓
# test_0363    | Pred=B  | GT=B  | ✓
# test_0364    | Pred=B  | GT=B  | ✓
# test_0365    | Pred=C  | GT=C  | ✓
# test_0366    | Pred=C  | GT=C  | ✓
# test_0367    | Pred=C  | GT=C  | ✓
# test_0368    | Pred=A  | GT=B  | ✗
# test_0369    | Pred=A  | GT=A  | ✓
# test_0370    | Pred=C  | GT=C  | ✓
# test_0371    | Pred=B  | GT=B  | ✓
# test_0372    | Pred=A  | GT=A  | ✓
# test_0373    | Pred=B  | GT=B  | ✓
# test_0374    | Pred=B  | GT=A  | ✗
# test_0375    | Pred=C  | GT=C  | ✓
# test_0376    | Pred=D  | GT=C  | ✗
# test_0377    | Pred=D  | GT=D  | ✓
# test_0378    | Pred=D  | GT=D  | ✓
# test_0379    | Pred=B  | GT=B  | ✓
# test_0380    | Pred=B  | GT=B  | ✓
# test_0381    | Pred=E  | GT=E  | ✓
# test_0382    | Pred=B  | GT=B  | ✓
# test_0383    | Pred=B  | GT=B  | ✓
# test_0384    | Pred=B  | GT=A  | ✗
# test_0385    | Pred=B  | GT=B  | ✓
# test_0386    | Pred=A  | GT=A  | ✓
# test_0387    | Pred=C  | GT=C  | ✓
# test_0388    | Pred=C  | GT=C  | ✓
# test_0389    | Pred=C  | GT=A  | ✗
# test_0390    | Pred=A  | GT=A  | ✓
# test_0391    | Pred=A  | GT=A  | ✓
# test_0392    | Pred=B  | GT=B  | ✓
# test_0393    | Pred=B  | GT=B  | ✓
# test_0394    | Pred=A  | GT=A  | ✓
# test_0395    | Pred=A  | GT=A  | ✓
# test_0396    | Pred=B  | GT=D  | ✗
# test_0397    | Pred=T  | GT=E  | ✗
# test_0398    | Pred=D  | GT=D  | ✓
# test_0399    | Pred=D  | GT=D  | ✓
# test_0400    | Pred=A  | GT=A  | ✓
# test_0401    | Pred=B  | GT=A  | ✗
# test_0402    | Pred=E  | GT=E  | ✓
# test_0403    | Pred=A  | GT=A  | ✓
# test_0404    | Pred=C  | GT=C  | ✓
# test_0405    | Pred=C  | GT=C  | ✓
# test_0406    | Pred=B  | GT=B  | ✓
# test_0407    | Pred=B  | GT=B  | ✓
# test_0408    | Pred=A  | GT=A  | ✓
# test_0409    | Pred=B  | GT=B  | ✓
# test_0410    | Pred=B  | GT=B  | ✓
# test_0411    | Pred=C  | GT=C  | ✓
# test_0412    | Pred=A  | GT=A  | ✓
# test_0413    | Pred=A  | GT=A  | ✓
# test_0414    | Pred=D  | GT=D  | ✓
# test_0415    | Pred=D  | GT=D  | ✓
# test_0416    | Pred=B  | GT=B  | ✓
# test_0417    | Pred=D  | GT=D  | ✓
# test_0418    | Pred=A  | GT=D  | ✗
# test_0419    | Pred=A  | GT=A  | ✓
# test_0420    | Pred=A  | GT=A  | ✓
# test_0421    | Pred=A  | GT=A  | ✓
# test_0422    | Pred=A  | GT=A  | ✓
# test_0423    | Pred=D  | GT=D  | ✓
# test_0424    | Pred=B  | GT=B  | ✓
# test_0425    | Pred=D  | GT=D  | ✓
# test_0426    | Pred=B  | GT=B  | ✓
# test_0427    | Pred=B  | GT=B  | ✓
# test_0428    | Pred=C  | GT=C  | ✓
# test_0429    | Pred=B  | GT=B  | ✓
# test_0430    | Pred=A  | GT=A  | ✓
# test_0431    | Pred=C  | GT=C  | ✓
# test_0432    | Pred=C  | GT=C  | ✓
# test_0433    | Pred=A  | GT=B  | ✗
# test_0434    | Pred=B  | GT=B  | ✓
# test_0435    | Pred=A  | GT=A  | ✓
# test_0436    | Pred=C  | GT=C  | ✓
# test_0437    | Pred=B  | GT=B  | ✓
# test_0438    | Pred=C  | GT=C  | ✓
# test_0439    | Pred=A  | GT=A  | ✓
# test_0440    | Pred=B  | GT=A  | ✗
# test_0441    | Pred=A  | GT=B  | ✗
# test_0442    | Pred=A  | GT=A  | ✓
# test_0443    | Pred=C  | GT=C  | ✓
# test_0444    | Pred=A  | GT=A  | ✓
# test_0445    | Pred=B  | GT=B  | ✓
# test_0446    | Pred=A  | GT=A  | ✓
# test_0447    | Pred=B  | GT=B  | ✓
# test_0448    | Pred=A  | GT=A  | ✓
# test_0449    | Pred=A  | GT=D  | ✗
# test_0450    | Pred=A  | GT=A  | ✓
# test_0451    | Pred=A  | GT=B  | ✗
# test_0452    | Pred=G  | GT=B  | ✗
# test_0453    | Pred=A  | GT=A  | ✓
# test_0454    | Pred=D  | GT=B  | ✗
# test_0455    | Pred=B  | GT=B  | ✓
# test_0456    | Pred=C  | GT=C  | ✓
# test_0457    | Pred=D  | GT=D  | ✓
# test_0458    | Pred=D  | GT=D  | ✓
# test_0459    | Pred=C  | GT=C  | ✓
# test_0460    | Pred=A  | GT=A  | ✓
# test_0461    | Pred=B  | GT=B  | ✓
# test_0462    | Pred=B  | GT=C  | ✗
# test_0463    | Pred=D  | GT=D  | ✓
# ====================================================================================================
# Correct : 215/263
# Accuracy: 81.75%
# ====================================================================================================
